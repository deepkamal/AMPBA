# %%
from pyspark import SparkConf, SparkContext, SparkFiles
from pyspark.sql import *


app_name = "ampba.batch15.fp1.group10_assignment.FoodRecommenderModel"

spark = SparkSession.builder \
.master("local") \
.appName(app_name) \
.getOrCreate()

# %%
# ML Libs

from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.sql import Row

from pyspark.ml.fpm import FPGrowth

# %%
# Name to ID mapping of each Data field


# Collaborative Filtering using ALS - user, ordered-food-Id, rating

# Association Mapping using FPGrowth - orderid, foodIds set,

# Association Mapping using FPGrowth- foodId, core ingredient set,

### ### Historical Based F1 Scoring

# consolidator - Union(Distinct) x coeff. 

# Set reduction by User Factor - allergic, medical(diabetic,Gouts(no protein)), veg/non-veg,like/dislike

# Food Ids - mapper -> Food Names -> send Front End in JSON form
