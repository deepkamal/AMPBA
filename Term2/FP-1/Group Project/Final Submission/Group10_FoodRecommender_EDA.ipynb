# %%
# %fs ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/EDA.ipynb</td><td>EDA.ipynb</td><td>3946</td></tr><tr><td>dbfs:/FileStore/tables/Zomato_reduced.csv</td><td>Zomato_reduced.csv</td><td>126883203</td></tr><tr><td>dbfs:/FileStore/tables/lab/</td><td>lab/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/restaurants_in_India-1.csv</td><td>restaurants_in_India-1.csv</td><td>113670506</td></tr><tr><td>dbfs:/FileStore/tables/restaurants_in_India.csv</td><td>restaurants_in_India.csv</td><td>113670506</td></tr></tbody></table></div>

# %%
res_df1 = spark.read.format("csv").option("header","true").option("inferSchema", "true").load("/FileStore/tables/Zomato_reduced.csv")
res_df2 = spark.read.format("csv").option("header","true").option("inferSchema", "true").load("/FileStore/tables/restaurants_in_India.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
res_df1.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[121]: [&#39;url&#39;,
#  &#39;address&#39;,
#  &#39;name&#39;,
#  &#39;online_order&#39;,
#  &#39;book_table&#39;,
#  &#39;rate&#39;,
#  &#39;votes&#39;,
#  &#39;phone&#39;,
#  &#39;location&#39;,
#  &#39;rest_type&#39;,
#  &#39;dish_liked&#39;,
#  &#39;cuisines&#39;,
#  &#39;approx_cost(for two people)&#39;,
#  &#39;reviews_list&#39;,
#  &#39;menu_item&#39;,
#  &#39;listed_in(type)&#39;,
#  &#39;listed_in(city)&#39;,
#  &#39;liked_food_from_review&#39;,
#  &#39;menus_combined&#39;,
#  &#39;location_latitude&#39;,
#  &#39;location_longitude&#39;,
#  &#39;_c21&#39;,
#  &#39;_c22&#39;,
#  &#39;_c23&#39;,
#  &#39;_c24&#39;,
#  &#39;_c25&#39;,
#  &#39;_c26&#39;,
#  &#39;_c27&#39;,
#  &#39;_c28&#39;,
#  &#39;_c29&#39;,
#  &#39;_c30&#39;,
#  &#39;_c31&#39;,
#  &#39;_c32&#39;,
#  &#39;_c33&#39;,
#  &#39;_c34&#39;,
#  &#39;_c35&#39;,
#  &#39;_c36&#39;,
#  &#39;_c37&#39;,
#  &#39;_c38&#39;,
#  &#39;_c39&#39;,
#  &#39;_c40&#39;,
#  &#39;_c41&#39;,
#  &#39;_c42&#39;,
#  &#39;_c43&#39;,
#  &#39;_c44&#39;,
#  &#39;_c45&#39;,
#  &#39;_c46&#39;,
#  &#39;_c47&#39;,
#  &#39;_c48&#39;,
#  &#39;_c49&#39;,
#  &#39;_c50&#39;,
#  &#39;_c51&#39;,
#  &#39;_c52&#39;,
#  &#39;_c53&#39;,
#  &#39;_c54&#39;,
#  &#39;_c55&#39;,
#  &#39;_c56&#39;,
#  &#39;_c57&#39;,
#  &#39;_c58&#39;,
#  &#39;_c59&#39;,
#  &#39;_c60&#39;,
#  &#39;_c61&#39;,
#  &#39;_c62&#39;,
#  &#39;_c63&#39;,
#  &#39;_c64&#39;,
#  &#39;_c65&#39;,
#  &#39;_c66&#39;,
#  &#39;_c67&#39;,
#  &#39;_c68&#39;,
#  &#39;_c69&#39;,
#  &#39;_c70&#39;,
#  &#39;_c71&#39;,
#  &#39;_c72&#39;,
#  &#39;_c73&#39;,
#  &#39;_c74&#39;,
#  &#39;_c75&#39;,
#  &#39;_c76&#39;,
#  &#39;_c77&#39;,
#  &#39;_c78&#39;,
#  &#39;_c79&#39;,
#  &#39;_c80&#39;,
#  &#39;_c81&#39;,
#  &#39;_c82&#39;,
#  &#39;_c83&#39;,
#  &#39;_c84&#39;,
#  &#39;_c85&#39;,
#  &#39;_c86&#39;,
#  &#39;_c87&#39;,
#  &#39;_c88&#39;,
#  &#39;_c89&#39;,
#  &#39;_c90&#39;,
#  &#39;_c91&#39;,
#  &#39;_c92&#39;,
#  &#39;_c93&#39;,
#  &#39;_c94&#39;,
#  &#39;_c95&#39;,
#  &#39;_c96&#39;,
#  &#39;_c97&#39;,
#  &#39;_c98&#39;,
#  &#39;_c99&#39;,
#  &#39;_c100&#39;,
#  &#39;_c101&#39;,
#  &#39;_c102&#39;,
#  &#39;_c103&#39;,
#  &#39;_c104&#39;,
#  &#39;_c105&#39;,
#  &#39;_c106&#39;,
#  &#39;_c107&#39;,
#  &#39;_c108&#39;,
#  &#39;_c109&#39;,
#  &#39;_c110&#39;,
#  &#39;_c111&#39;,
#  &#39;_c112&#39;,
#  &#39;_c113&#39;,
#  &#39;_c114&#39;,
#  &#39;_c115&#39;,
#  &#39;_c116&#39;,
#  &#39;_c117&#39;,
#  &#39;_c118&#39;,
#  &#39;_c119&#39;,
#  &#39;_c120&#39;,
#  &#39;_c121&#39;,
#  &#39;_c122&#39;,
#  &#39;_c123&#39;,
#  &#39;_c124&#39;,
#  &#39;_c125&#39;,
#  &#39;_c126&#39;,
#  &#39;_c127&#39;,
#  &#39;_c128&#39;,
#  &#39;_c129&#39;,
#  &#39;_c130&#39;,
#  &#39;_c131&#39;,
#  &#39;_c132&#39;,
#  &#39;_c133&#39;,
#  &#39;_c134&#39;,
#  &#39;_c135&#39;,
#  &#39;_c136&#39;,
#  &#39;_c137&#39;,
#  &#39;_c138&#39;,
#  &#39;_c139&#39;,
#  &#39;_c140&#39;,
#  &#39;_c141&#39;,
#  &#39;_c142&#39;,
#  &#39;_c143&#39;,
#  &#39;_c144&#39;,
#  &#39;_c145&#39;,
#  &#39;_c146&#39;,
#  &#39;_c147&#39;,
#  &#39;_c148&#39;,
#  &#39;_c149&#39;,
#  &#39;_c150&#39;,
#  &#39;_c151&#39;,
#  &#39;_c152&#39;,
#  &#39;_c153&#39;,
#  &#39;_c154&#39;,
#  &#39;_c155&#39;,
#  &#39;_c156&#39;,
#  &#39;_c157&#39;,
#  &#39;_c158&#39;,
#  &#39;_c159&#39;,
#  &#39;_c160&#39;,
#  &#39;_c161&#39;,
#  &#39;_c162&#39;,
#  &#39;_c163&#39;,
#  &#39;_c164&#39;,
#  &#39;_c165&#39;,
#  &#39;_c166&#39;,
#  &#39;_c167&#39;,
#  &#39;_c168&#39;,
#  &#39;_c169&#39;,
#  &#39;_c170&#39;,
#  &#39;_c171&#39;,
#  &#39;_c172&#39;,
#  &#39;_c173&#39;,
#  &#39;_c174&#39;,
#  &#39;_c175&#39;,
#  &#39;_c176&#39;,
#  &#39;_c177&#39;,
#  &#39;_c178&#39;,
#  &#39;_c179&#39;,
#  &#39;_c180&#39;,
#  &#39;_c181&#39;,
#  &#39;_c182&#39;,
#  &#39;_c183&#39;,
#  &#39;_c184&#39;,
#  &#39;_c185&#39;,
#  &#39;_c186&#39;,
#  &#39;_c187&#39;,
#  &#39;_c188&#39;,
#  &#39;_c189&#39;,
#  &#39;_c190&#39;,
#  &#39;_c191&#39;,
#  &#39;_c192&#39;,
#  &#39;_c193&#39;,
#  &#39;_c194&#39;,
#  &#39;_c195&#39;,
#  &#39;_c196&#39;,
#  &#39;_c197&#39;,
#  &#39;_c198&#39;,
#  &#39;_c199&#39;,
#  &#39;_c200&#39;,
#  &#39;_c201&#39;,
#  &#39;_c202&#39;,
#  &#39;_c203&#39;,
#  &#39;_c204&#39;,
#  &#39;_c205&#39;,
#  &#39;_c206&#39;,
#  &#39;_c207&#39;,
#  &#39;_c208&#39;,
#  &#39;_c209&#39;,
#  &#39;_c210&#39;,
#  &#39;_c211&#39;,
#  &#39;_c212&#39;,
#  &#39;_c213&#39;,
#  &#39;_c214&#39;,
#  &#39;_c215&#39;,
#  &#39;_c216&#39;,
#  &#39;_c217&#39;,
#  &#39;_c218&#39;,
#  &#39;_c219&#39;,
#  &#39;_c220&#39;,
#  &#39;_c221&#39;,
#  &#39;_c222&#39;,
#  &#39;_c223&#39;,
#  &#39;_c224&#39;,
#  &#39;_c225&#39;,
#  &#39;_c226&#39;,
#  &#39;_c227&#39;,
#  &#39;_c228&#39;,
#  &#39;_c229&#39;,
#  &#39;_c230&#39;,
#  &#39;_c231&#39;,
#  &#39;_c232&#39;,
#  &#39;_c233&#39;,
#  &#39;_c234&#39;,
#  &#39;_c235&#39;,
#  &#39;_c236&#39;,
#  &#39;_c237&#39;,
#  &#39;_c238&#39;,
#  &#39;_c239&#39;,
#  &#39;_c240&#39;,
#  &#39;_c241&#39;,
#  &#39;_c242&#39;,
#  &#39;_c243&#39;,
#  &#39;_c244&#39;,
#  &#39;_c245&#39;,
#  &#39;_c246&#39;,
#  &#39;_c247&#39;,
#  &#39;_c248&#39;,
#  &#39;_c249&#39;,
#  &#39;_c250&#39;,
#  &#39;_c251&#39;,
#  &#39;_c252&#39;,
#  &#39;_c253&#39;,
#  &#39;_c254&#39;,
#  &#39;_c255&#39;,
#  &#39;_c256&#39;,
#  &#39;_c257&#39;,
#  &#39;_c258&#39;,
#  &#39;_c259&#39;,
#  &#39;_c260&#39;,
#  &#39;_c261&#39;,
#  &#39;_c262&#39;,
#  &#39;_c263&#39;,
#  &#39;_c264&#39;,
#  &#39;_c265&#39;,
#  &#39;_c266&#39;,
#  &#39;_c267&#39;,
#  &#39;_c268&#39;,
#  &#39;_c269&#39;,
#  &#39;_c270&#39;,
#  &#39;_c271&#39;,
#  &#39;_c272&#39;,
#  &#39;_c273&#39;,
#  &#39;_c274&#39;,
#  &#39;_c275&#39;,
#  &#39;_c276&#39;,
#  &#39;_c277&#39;,
#  &#39;_c278&#39;,
#  &#39;_c279&#39;,
#  &#39;_c280&#39;,
#  &#39;_c281&#39;,
#  &#39;_c282&#39;,
#  &#39;_c283&#39;,
#  &#39;_c284&#39;,
#  &#39;_c285&#39;,
#  &#39;_c286&#39;,
#  &#39;_c287&#39;,
#  &#39;_c288&#39;,
#  &#39;_c289&#39;,
#  &#39;_c290&#39;,
#  &#39;_c291&#39;,
#  &#39;_c292&#39;,
#  &#39;_c293&#39;,
#  &#39;_c294&#39;,
#  &#39;_c295&#39;,
#  &#39;_c296&#39;,
#  &#39;_c297&#39;,
#  &#39;_c298&#39;,
#  &#39;_c299&#39;,
#  &#39;_c300&#39;,
#  &#39;_c301&#39;,
#  &#39;_c302&#39;,
#  &#39;_c303&#39;,
#  &#39;_c304&#39;,
#  &#39;_c305&#39;,
#  &#39;_c306&#39;,
#  &#39;_c307&#39;,
#  &#39;_c308&#39;,
#  &#39;_c309&#39;,
#  &#39;_c310&#39;,
#  &#39;_c311&#39;,
#  &#39;_c312&#39;,
#  &#39;_c313&#39;,
#  &#39;_c314&#39;,
#  &#39;_c315&#39;,
#  &#39;_c316&#39;,
#  &#39;_c317&#39;,
#  &#39;_c318&#39;,
#  &#39;_c319&#39;,
#  &#39;_c320&#39;,
#  &#39;_c321&#39;,
#  &#39;_c322&#39;,
#  &#39;_c323&#39;,
#  &#39;_c324&#39;,
#  &#39;_c325&#39;,
#  &#39;_c326&#39;,
#  &#39;_c327&#39;,
#  &#39;_c328&#39;,
#  &#39;_c329&#39;,
#  &#39;_c330&#39;,
#  &#39;_c331&#39;,
#  &#39;_c332&#39;,
#  &#39;_c333&#39;,
#  &#39;_c334&#39;,
#  &#39;_c335&#39;,
#  &#39;_c336&#39;,
#  &#39;_c337&#39;,
#  &#39;_c338&#39;,
#  &#39;_c339&#39;,
#  &#39;_c340&#39;,
#  &#39;_c341&#39;,
#  &#39;_c342&#39;,
#  &#39;_c343&#39;,
#  &#39;_c344&#39;,
#  &#39;_c345&#39;,
#  &#39;_c346&#39;,
#  &#39;_c347&#39;,
#  &#39;_c348&#39;,
#  &#39;_c349&#39;,
#  &#39;_c350&#39;,
#  &#39;_c351&#39;,
#  &#39;_c352&#39;,
#  &#39;_c353&#39;,
#  &#39;_c354&#39;,
#  &#39;_c355&#39;,
#  &#39;_c356&#39;,
#  &#39;_c357&#39;,
#  &#39;_c358&#39;,
#  &#39;_c359&#39;,
#  &#39;_c360&#39;,
#  &#39;_c361&#39;,
#  &#39;_c362&#39;,
#  &#39;_c363&#39;,
#  &#39;_c364&#39;,
#  &#39;_c365&#39;,
#  &#39;_c366&#39;,
#  &#39;_c367&#39;,
#  &#39;_c368&#39;,
#  &#39;_c369&#39;,
#  &#39;_c370&#39;,
#  &#39;_c371&#39;,
#  &#39;_c372&#39;,
#  &#39;_c373&#39;,
#  &#39;_c374&#39;,
#  &#39;_c375&#39;,
#  &#39;_c376&#39;,
#  &#39;_c377&#39;,
#  &#39;_c378&#39;,
#  &#39;_c379&#39;,
#  &#39;_c380&#39;,
#  &#39;_c381&#39;,
#  &#39;_c382&#39;,
#  &#39;_c383&#39;,
#  &#39;_c384&#39;,
#  &#39;_c385&#39;,
#  &#39;_c386&#39;,
#  &#39;_c387&#39;,
#  &#39;_c388&#39;,
#  &#39;_c389&#39;,
#  &#39;_c390&#39;,
#  &#39;_c391&#39;,
#  &#39;_c392&#39;,
#  &#39;_c393&#39;,
#  &#39;_c394&#39;,
#  &#39;_c395&#39;,
#  &#39;_c396&#39;,
#  &#39;_c397&#39;,
#  &#39;_c398&#39;,
#  &#39;_c399&#39;,
#  &#39;_c400&#39;,
#  &#39;_c401&#39;,
#  &#39;_c402&#39;,
#  &#39;_c403&#39;,
#  &#39;_c404&#39;,
#  &#39;_c405&#39;,
#  &#39;_c406&#39;,
#  &#39;_c407&#39;,
#  &#39;_c408&#39;,
#  &#39;_c409&#39;,
#  &#39;_c410&#39;,
#  &#39;_c411&#39;,
#  &#39;_c412&#39;,
#  &#39;_c413&#39;,
#  &#39;_c414&#39;,
#  &#39;_c415&#39;,
#  &#39;_c416&#39;,
#  &#39;_c417&#39;,
#  &#39;_c418&#39;,
#  &#39;_c419&#39;,
#  &#39;_c420&#39;,
#  &#39;_c421&#39;,
#  &#39;_c422&#39;

# %%
res_df2.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[122]: [&#39;res_id&#39;,
#  &#39;name&#39;,
#  &#39;establishment&#39;,
#  &#39;url&#39;,
#  &#39;address&#39;,
#  &#39;city&#39;,
#  &#39;city_id&#39;,
#  &#39;locality&#39;,
#  &#39;latitude&#39;,
#  &#39;longitude&#39;,
#  &#39;zipcode&#39;,
#  &#39;country_id&#39;,
#  &#39;locality_verbose&#39;,
#  &#39;cuisines&#39;,
#  &#39;timings&#39;,
#  &#39;average_cost_for_two&#39;,
#  &#39;price_range&#39;,
#  &#39;currency&#39;,
#  &#39;highlights&#39;,
#  &#39;aggregate_rating&#39;,
#  &#39;rating_text&#39;,
#  &#39;votes&#39;,
#  &#39;photo_count&#39;,
#  &#39;opentable_support&#39;,
#  &#39;delivery&#39;,
#  &#39;takeaway&#39;]</div>

# %%
res_df2.summary
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[123]: &lt;bound method DataFrame.summary of DataFrame[res_id: string, name: string, establishment: string, url: string, address: string, city: string, city_id: string, locality: string, latitude: string, longitude: string, zipcode: string, country_id: string, locality_verbose: string, cuisines: string, timings: string, average_cost_for_two: string, price_range: string, currency: string, highlights: string, aggregate_rating: string, rating_text: string, votes: string, photo_count: string, opentable_support: string, delivery: string, takeaway: int]&gt;</div>

# %%
res_df2=res_df2.withColumn("average_cost_for_two",res_df2.average_cost_for_two.cast('double'))
res_df2=res_df2.withColumn("price_range",res_df2.price_range.cast('double'))
res_df2=res_df2.withColumn("aggregate_rating",res_df2.aggregate_rating.cast('double'))
res_df2=res_df2.withColumn("votes",res_df2.votes.cast('double'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Finding Count of Null and Missing values in Restaurant Data
from pyspark.sql.functions import isnan, when, count, col
res_df2.select([count(when(isnan(x) | col(x).isNull(), x)).alias(x) for x in res_df2.columns]).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+-------------+---+-------+----+-------+--------+--------+---------+-------+----------+----------------+--------+-------+--------------------+-----------+--------+----------+----------------+-----------+-----+-----------+-----------------+--------+--------+
# res_id|name|establishment|url|address|city|city_id|locality|latitude|longitude|zipcode|country_id|locality_verbose|cuisines|timings|average_cost_for_two|price_range|currency|highlights|aggregate_rating|rating_text|votes|photo_count|opentable_support|delivery|takeaway|
# +------+----+-------------+---+-------+----+-------+--------+--------+---------+-------+----------+----------------+--------+-------+--------------------+-----------+--------+----------+----------------+-----------+-----+-----------+-----------------+--------+--------+
#      3|  83|          121|122|    256| 602|    625|     639|     614|      623| 163674|       602|             602|    1993|   4476|                 921|       1002|     734|       734|             775|        735|  741|        858|              988|    1038|    1076|
# +------+----+-------------+---+-------+----+-------+--------+--------+---------+-------+----------+----------------+--------+-------+--------------------+-----------+--------+----------+----------------+-----------+-----+-----------+-----------------+--------+--------+
#
# </div>

# %%
res_df2.describe().select('average_cost_for_two','price_range','aggregate_rating','votes').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------------------+------------------+-----------------+
# average_cost_for_two|       price_range|  aggregate_rating|            votes|
# +--------------------+------------------+------------------+-----------------+
#               211625|            211544|            211771|           211805|
#    595.4745119905493| 1.885106644480581| 3.805275982074953|377.7419522674158|
#    606.6735553951554|1.2657535441759222|28.833821152740825|925.6341612833917|
#                  0.0|               0.0|              -1.0|            -18.0|
#              30000.0|             414.0|            3261.0|          42539.0|
# +--------------------+------------------+------------------+-----------------+
#
# </div>

# %%
#it is observed that the minimum value for the fields such as "average_cost_for_two", "price_range" are zero (0) and "aggregate_rating", "votes" are -1. Replacing 0 and -1 with NaN in these fields.
import numpy as np
from pyspark.sql.functions import when
res_df2=res_df2.withColumn("average_cost_for_two",when(res_df2.average_cost_for_two==0,np.nan).otherwise(res_df2.average_cost_for_two))
res_df2=res_df2.withColumn("average_cost_for_two",when(res_df2.average_cost_for_two==1,np.nan).otherwise(res_df2.average_cost_for_two))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
res_df2=res_df2.withColumn("price_range",when(res_df2.price_range==0,np.nan).otherwise(res_df2.price_range))
#res_df2=res_df2.withColumn("aggregate_rating",when(res_df2.aggregate_rating==-1,np.nan).otherwise(res_df2.aggregate_rating))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
res_df2=res_df2.withColumn("votes",when(res_df2.votes==-18,np.nan).otherwise(res_df2.votes))
res_df2=res_df2.withColumn("votes",when(res_df2.votes==-3,np.nan).otherwise(res_df2.votes))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
res_df2.describe().select('average_cost_for_two','price_range','aggregate_rating','votes').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----------+------------------+------+
# average_cost_for_two|price_range|  aggregate_rating| votes|
# +--------------------+-----------+------------------+------+
#               211625|     211544|            211771|211805|
#                  NaN|        NaN| 3.805275982074953|   NaN|
#                  NaN|        NaN|28.833821152740825|   NaN|
#                  2.0|        1.0|              -1.0|  -1.0|
#                  NaN|        NaN|            3261.0|   NaN|
# +--------------------+-----------+------------------+------+
#
# </div>

# %%
res_df2.summary
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[131]: &lt;bound method DataFrame.summary of DataFrame[res_id: string, name: string, establishment: string, url: string, address: string, city: string, city_id: string, locality: string, latitude: string, longitude: string, zipcode: string, country_id: string, locality_verbose: string, cuisines: string, timings: string, average_cost_for_two: double, price_range: double, currency: string, highlights: string, aggregate_rating: double, rating_text: string, votes: double, photo_count: string, opentable_support: string, delivery: string, takeaway: int]&gt;</div>

# %%
# So we have replaced all "0" and "1" with NaN. Now, we can simply impute the NaN by calling an imputer.
from pyspark.ml.feature import Imputer
imputer=Imputer(inputCols=["average_cost_for_two","price_range","aggregate_rating","votes"],outputCols=["average_cost_for_two","price_range","aggregate_rating","votes"])
model=imputer.fit(res_df2)
res_df2=model.transform(res_df2)
res_df2.select("average_cost_for_two","price_range","aggregate_rating","votes").show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----------+----------------+------+
# average_cost_for_two|price_range|aggregate_rating| votes|
# +--------------------+-----------+----------------+------+
#                700.0|        2.0|             4.4| 814.0|
#                600.0|        2.0|             4.4|1203.0|
#                300.0|        1.0|             4.2| 801.0|
#                300.0|        1.0|             4.3| 693.0|
#               1000.0|        3.0|             4.9| 470.0|
# +--------------------+-----------+----------------+------+
# only showing top 5 rows
#
# </div>

# %%
# combining all the features in one single feature vector
cols=res_df2.select("average_cost_for_two","price_range","aggregate_rating","votes").columns
#cols.remove("price_range")
# Import vector assembler
from pyspark.ml.feature import VectorAssembler
assembler = VectorAssembler(inputCols=cols,outputCol="features2")
# Using Transform method to transform the dataset
res_df2=assembler.transform(res_df2)
res_df2.select("features2").show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------------+
# features2             |
# +----------------------+
# [700.0,2.0,4.4,814.0] |
# [600.0,2.0,4.4,1203.0]|
# [300.0,1.0,4.2,801.0] |
# [300.0,1.0,4.3,693.0] |
# [1000.0,3.0,4.9,470.0]|
# [400.0,2.0,4.0,707.0] |
# [500.0,2.0,4.2,647.0] |
# [400.0,2.0,3.8,617.0] |
# [500.0,2.0,3.4,322.0] |
# [1000.0,3.0,4.4,289.0]|
# [1200.0,3.0,4.4,683.0]|
# [700.0,2.0,4.4,523.0] |
# [700.0,2.0,4.1,626.0] |
# [300.0,1.0,4.1,361.0] |
# [700.0,2.0,4.1,474.0] |
# [400.0,2.0,3.5,490.0] |
# [1600.0,4.0,4.6,915.0]|
# [500.0,2.0,4.3,837.0] |
# [400.0,2.0,4.1,362.0] |
# [300.0,1.0,4.4,490.0] |
# +----------------------+
# only showing top 20 rows
#
# </div>

# %%
# Using StandardScaler to scalerize the newly created "feature" column
from pyspark.ml.feature import StandardScaler
standardscaler=StandardScaler().setInputCol("features2").setOutputCol("Scaled_features")
res_df2=standardscaler.fit(res_df2).transform(res_df2)
res_df2.select("features2","Scaled_features").show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+
#            features2|     Scaled_features|
# +--------------------+--------------------+
# [700.0,2.0,4.4,81...|[1.16195637810345...|
# [600.0,2.0,4.4,12...|[0.99596260980295...|
# [300.0,1.0,4.2,80...|[0.49798130490147...|
# [300.0,1.0,4.3,69...|[0.49798130490147...|
# [1000.0,3.0,4.9,4...|[1.65993768300492...|
# +--------------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
# splitting the dataset in training and testing set
train, test = res_df2.randomSplit([0.8, 0.2], seed=12345)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# checking whether their is imbalance in the dataset - number of records with 0 rating
dataset_size=float(train.select("aggregate_rating").count())
numPositives=train.select("aggregate_rating").where('aggregate_rating == 0').count()
per_ones=(float(numPositives)/float(dataset_size))*100
numNegatives=float(dataset_size-numPositives)
print('The number of zeros are {}'.format(numPositives))
print('Percentage of zeros are {}'.format(per_ones))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The number of zeros are 18862
# Percentage of zeros are 11.102412723452096
# </div>

# %%
#Handling of imbalance class handling
# Since the percentage of ones in the dataset is just 11.1 % ,their is slight imbalance in the dataset.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#In the dataset (train) we have 11.1 % negatives and 88.9 % positives. Therefore,logistic loss objective function should treat the positive class (aggregate_rating > 0) with slightly higher weight. For this purpose we calculate the BalancingRatio as follows:

#BalancingRatio= numNegatives/dataset_size

#Then against every aggregate_rating > 0, we put BalancingRatio in column "classWeights", and against every aggregate_rating = 0, we put 1-BalancingRatio in column "classWeights"

#In this way, we assign higher weightage to the minority class (i.e. positive class)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
BalancingRatio= numNegatives/dataset_size
print('BalancingRatio = {}'.format(BalancingRatio))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">BalancingRatio = 0.8889758727654791
# </div>

# %%
train=train.withColumn("classWeights", when(train.aggregate_rating > 0,BalancingRatio).otherwise(1-BalancingRatio))
train.select("classWeights").show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+
#        classWeights|
# +-------------------+
#  0.8889758727654791|
#  0.8889758727654791|
#  0.8889758727654791|
# 0.11102412723452093|
#  0.8889758727654791|
# +-------------------+
# only showing top 5 rows
#
# </div>

# %%
# Feature selection using chisquareSelector
from pyspark.ml.feature import ChiSqSelector
# css=ChiSqSelector().setFeaturesCol('Scaled_features').setLabelCol("Outcome").setOutputCol("Aspect")
css = ChiSqSelector(featuresCol='Scaled_features',outputCol='Aspect',labelCol='aggregate_rating',fpr=0.05)
train=css.fit(train).transform(train)
test=css.fit(test).transform(test)
test.select("Aspect").show(5,truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------------------------------------------------------------------+
# Aspect                                                                        |
# +------------------------------------------------------------------------------+
# [0.9983430432122783,1.492853596878108,0.13221392182169653,0.40880954747082987]|
# [0.9959626098029576,1.583832452458533,0.14245407744995417,1.114696794945302]  |
# [2.6559002928078868,3.167664904917066,0.15635203622555946,2.465319707655726]  |
# [2.6559002928078868,3.167664904917066,0.15635203622555946,2.465319707655726]  |
# [2.6559002928078868,3.167664904917066,0.15635203622555946,2.465319707655726]  |
# +------------------------------------------------------------------------------+
# only showing top 5 rows
#
# </div>
