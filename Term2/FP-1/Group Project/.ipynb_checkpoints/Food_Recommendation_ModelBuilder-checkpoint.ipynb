# %%
from pyspark import SparkConf, SparkContext, SparkFiles
from pyspark.sql import *


app_name = "ampba.batch15.fp1.group10_assignment.FoodRecommenderModel"

spark = SparkSession.builder \
.master("local") \
.appName(app_name) \
.getOrCreate()

# %%
# ML Libs

from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.sql import Row

from pyspark.ml.fpm import FPGrowth

# %%
# Collaborative Filtering using ALS - user, ordered-food-Id, rating
# Association Mapping using FPGrowth- orderid, foodId,
# Association Mapping using FPGrowth- foodId, ingredient set,
