# %% [markdown]
# ## Spark Developer Training
#
# **Manaranjan Pradhan**<br/>
# **manaranjan@enablecloud.com**<br/>
# *This notebook is given as part of Spark Training to Participants. Forwarding others is strictly prohibited.*

# %% [markdown]
# # Create a Cluster
#
# - Click on **Clusters** on the left menu
# - Enter the **cluster Name**
# - Select **Runtime Version** (keep default for the lab)
# - Select **Availability Zone**

# %% [markdown]
# # Creating a new notebook (Demo)
#
# - Create a new notebook
# - Click on **Workspace** on the left menu and go to your directory
# - Righ click in the directory and select **Create -> Notebook**
# - Select Default Language and Cluster (The cluster can be changed anytime)

# %% [markdown]
# # Lab: Markdown

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
#
# This is a comment line.
#
# This is **bold** and this is *italic*
#
# This is a list of things
# - item 1
# - item 2
#
# This is a numbered list of things
# 0. item 1
# 0. item 2

# %% [markdown]
# # Lab: Writing Code

# %%
# %python 

print("Hello")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %scala

print("Hello")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Hello</div>

# %%
# %sql

SELECT "Hello"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Hello</th></tr></thead><tbody><tr><td>Hello</td></tr></tbody></table></div>

# %% [markdown]
# # Lab: Working with the file system

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td></tr><tr><td>dbfs:/local_disk0/</td><td>local_disk0/</td><td>0</td></tr><tr><td>dbfs:/ml/</td><td>ml/</td><td>0</td></tr><tr><td>dbfs:/mnt/</td><td>mnt/</td><td>0</td></tr><tr><td>dbfs:/tmp/</td><td>tmp/</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls databricks-datasets/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs help
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
# ...

# %% [markdown]
# # Lab: Mounting External Filesystems

# %% [markdown]
# The following code code is to ensure the mount point does not exist already

# %%
# %fs unmount /mnt/mylab
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/mylab has been unmounted.
# res5: Boolean = true
# </div>

# %%
ACCESS_KEY = "AKIAJRRNCFR47PCOXWKA"
SECRET_KEY = "GpsWDdZhCYGXjkp2o3aEXwswGP5JxXiTogRCnuBY"
ENCODED_SECRET_KEY = SECRET_KEY.replace("/", "%2F")

AWS_BUCKET_NAME = "baiclass"
MOUNT_NAME = "mylab"

dbutils.fs.mount("s3a://%s:%s@%s" % (ACCESS_KEY, ENCODED_SECRET_KEY, AWS_BUCKET_NAME), "/mnt/%s" % MOUNT_NAME)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: True</div>

# %%
# %fs ls /mnt/mylab
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/mylab/NASA_access_log_Aug95.gz</td><td>NASA_access_log_Aug95.gz</td><td>16633316</td></tr><tr><td>dbfs:/mnt/mylab/rossmansales.csv</td><td>rossmansales.csv</td><td>38057952</td></tr><tr><td>dbfs:/mnt/mylab/rossmanstores.csv</td><td>rossmanstores.csv</td><td>45010</td></tr></tbody></table></div>
