# %% [markdown]
# ## Spark Developer Training
#
# **Manaranjan Pradhan**<br/>
# **manaranjan@enablecloud.com**<br/>
# *This notebook is given as part of Spark Training to Participants. Forwarding to others is strictly prohibited.*

# %%
from pyspark import SparkConf, SparkContext,SparkFiles
from pyspark.sql import *

spark = SparkSession.builder \
.master("local") \
.appName("BDM2-Local") \
.getOrCreate()

# %% [markdown]
# # Lab: Introduction to Spark DataFrames
#
# ## Data: Analyzing Movielens Data
#
# Note: The dataset is available at https://grouplens.org/datasets/movielens/

# %% [markdown]
# ### Things to learn
#
# * Reading a file into spark dataframes
# * Applying schema while reading records into a dataframe
# * Displaying records
# * Applying operations like distinct, grouping, sorting, aggregating, filtering etc.
# * Joining multiple dataframes
# * Utility functions like describing schema, showing records, rename columns, listing columns etc
#
# Documentation for Spark DataFrame APIs are available at
#
# http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://master:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[16]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>BDM2-S1W2</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Loading data onto DBFS
#
# - Go to **Data** on the left menu
# - Click on **Create Table**
# - Add **lab** to /FileStore/tables directory path
# - Drag and drop files **ratings.data** under **Files** section
#
# Repeat the above step for uploading **movies.dat** file.

# %%
# %fs rm -r /FileStore/tables/lab/topmovies
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = true
# </div>

# %%
# %fs ls /FileStore/tables/lab
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/lab/movies-1.dat</td><td>movies-1.dat</td><td>163560</td></tr><tr><td>dbfs:/FileStore/tables/lab/movies.dat</td><td>movies.dat</td><td>163560</td></tr><tr><td>dbfs:/FileStore/tables/lab/ratings-1.dat</td><td>ratings-1.dat</td><td>21593504</td></tr><tr><td>dbfs:/FileStore/tables/lab/ratings.dat</td><td>ratings.dat</td><td>21593504</td></tr><tr><td>dbfs:/FileStore/tables/lab/txnjsonsmall</td><td>txnjsonsmall</td><td>588495</td></tr></tbody></table></div>

# %% [markdown]
# ### Reading the ratings file
#
# All ratings are contained in the file ratings.csv. Each line of this file represents one rating of one movie by one user, and has the following format:
#
# userId,movieId,rating,timestamp
# The lines within this file are ordered first by userId, then, within user, by movieId.
# The columns are TAB separated.
#
# Ratings are made on a 5-star scale, with half-star increments (0.5 stars - 5.0 stars).
#
# Timestamps represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970.

# %%
ratings = (spark.read   
                .option("sep", "\t")
                .csv('ratings.dat'))

# %% [markdown]
# **Note:**  The details of the the csv reader is given in the url https://docs.databricks.com/data/data-sources/read-csv.html

# %%
# What is the data type of the ratings variable. It should be a dataframe.
ratings
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string]

# %% [markdown]
# ### Displaying Records

# %%
# Read the first few rows of the dataframe
ratings.show()
# Out:
# +---+----+---+---------+
# |_c0| _c1|_c2|      _c3|
# +---+----+---+---------+
# |  1|1193|  5|978300760|
# |  1| 661|  3|978302109|
# |  1| 914|  3|978301968|
# |  1|3408|  4|978300275|
# |  1|2355|  5|978824291|
# |  1|1197|  3|978302268|
# |  1|1287|  5|978302039|
# |  1|2804|  5|978300719|
# |  1| 594|  4|978302268|
# |  1| 919|  4|978301368|
# |  1| 595|  5|978824268|
# |  1| 938|  4|978301752|
# |  1|2398|  4|978302281|
# |  1|2918|  4|978302124|
# |  1|1035|  5|978301753|
# |  1|2791|  4|978302188|
# |  1|2687|  3|978824268|
# |  1|2018|  4|978301777|
# |  1|3105|  5|978301713|
# |  1|2797|  4|978302039|
# +---+----+---+---------+
# only showing top 20 rows

# %% [markdown]
# ### Describe the schema of the records

# %%
ratings.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)

# %%
ratings.schema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: StructType(List(StructField(_c0,StringType,true),StructField(_c1,StringType,true),StructField(_c2,StringType,true),StructField(_c3,StringType,true)))</div>

# %% [markdown]
# ### Apply the schema to the dataframe

# %%
from pyspark.sql.types import IntegerType, LongType, StringType, StructType, StructField

fields = StructType([StructField("userid", IntegerType(), True),
          StructField("movieid", IntegerType(), True),
          StructField("rating", IntegerType(), True),
          StructField("timestamp", LongType(), True) ])

# %% [markdown]
# ### Applying the schema, while reading the records

# %%
## Read the tab separated file. Which contains userid, movieid, ratings and timestamp
ratings_df = (spark.read   
                .option("sep", "\t")
                .schema(fields)
                .csv('ratings.dat'))

# %%
ratings_df.show()
# Out:
# +------+-------+------+---------+
# |userid|movieid|rating|timestamp|
# +------+-------+------+---------+
# |     1|   1193|     5|978300760|
# |     1|    661|     3|978302109|
# |     1|    914|     3|978301968|
# |     1|   3408|     4|978300275|
# |     1|   2355|     5|978824291|
# |     1|   1197|     3|978302268|
# |     1|   1287|     5|978302039|
# |     1|   2804|     5|978300719|
# |     1|    594|     4|978302268|
# |     1|    919|     4|978301368|
# |     1|    595|     5|978824268|
# |     1|    938|     4|978301752|
# |     1|   2398|     4|978302281|
# |     1|   2918|     4|978302124|
# |     1|   1035|     5|978301753|
# |     1|   2791|     4|978302188|
# |     1|   2687|     3|978824268|
# |     1|   2018|     4|978301777|
# |     1|   3105|     5|978301713|
# |     1|   2797|     4|978302039|
# +------+-------+------+---------+
# only showing top 20 rows

# %%
ratings_df.printSchema()
# Out:
# root
#  |-- userid: integer (nullable = true)
#  |-- movieid: integer (nullable = true)
#  |-- rating: integer (nullable = true)
#  |-- timestamp: long (nullable = true)

# %% [markdown]
# ### Dealing with bad Records
#
#
# Verify correctness of the data
# When reading CSV files with a specified schema, it is possible that the data in the files does not match the schema.
#
#
# - PERMISSIVE (default): nulls are inserted for fields that could not be parsed correctly
# - DROPMALFORMED: drops lines that contain fields that could not be parsed
# - FAILFAST: aborts the reading if any malformed data is found
#
# <code>
# sqlContext.read.format("csv").option("mode", "DROPMALFORMED").option("badRecordsPath", "/tmp/badRecordsPath")
# </code>

# %% [markdown]
# ### Show the list of columns in the dataframe

# %%
# Return a list of columns
ratings_df.columns
# Out:
# ['userid', 'movieid', 'rating', 'timestamp']

# %%
## How many records in the dataframe?
ratings_df.count()
# Out:
# 1000209

# %% [markdown]
# ### Drop a column

# %%
## We donot need the timestamp column.. let's drop it
ratings_df = ratings_df.drop( 'timestamp')

# %%
ratings_df.show()
# Out:
# +------+-------+------+
# |userid|movieid|rating|
# +------+-------+------+
# |     1|   1193|     5|
# |     1|    661|     3|
# |     1|    914|     3|
# |     1|   3408|     4|
# |     1|   2355|     5|
# |     1|   1197|     3|
# |     1|   1287|     5|
# |     1|   2804|     5|
# |     1|    594|     4|
# |     1|    919|     4|
# |     1|    595|     5|
# |     1|    938|     4|
# |     1|   2398|     4|
# |     1|   2918|     4|
# |     1|   1035|     5|
# |     1|   2791|     4|
# |     1|   2687|     3|
# |     1|   2018|     4|
# |     1|   3105|     5|
# |     1|   2797|     4|
# +------+-------+------+
# only showing top 20 rows

# %% [markdown]
# ### How many unique movies and users in the dataset

# %%
ratings_df.select("userid").distinct().count()
# Out:
# 6040

# %%
ratings_df.select("movieid").distinct().count()
# Out:
# 3706

# %% [markdown]
# ### Applying operations like groupby() and sort()

# %%
movie_counts = ratings_df.groupBy("movieid").count()

# %%
from pyspark.sql.functions import *
movie_counts = movie_counts.sort(desc("count"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movie_counts.show( 10 )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----+
# movieid|count|
# +-------+-----+
#    2858| 3428|
#     260| 2991|
#    1196| 2990|
#    1210| 2883|
#     480| 2672|
#    2028| 2653|
#     589| 2649|
#    2571| 2590|
#    1270| 2583|
#     593| 2578|
# +-------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ### Applying an aggregation function to the group by

# %%
avg_ratings = ratings_df.groupBy("movieid").agg( {"rating":"avg"} )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
avg_ratings.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- movieid: integer (nullable = true)
# -- avg(rating): double (nullable = true)
#
# </div>

# %%
avg_ratings = avg_ratings.sort( desc( "avg(rating)" ) )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
avg_ratings.show( 10 )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------+
# movieid|avg(rating)|
# +-------+-----------+
#     787|        5.0|
#     989|        5.0|
#    3172|        5.0|
#    3280|        5.0|
#    1830|        5.0|
#    3881|        5.0|
#    3607|        5.0|
#    3382|        5.0|
#    3656|        5.0|
#    3233|        5.0|
# +-------+-----------+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ### Joining multiple dataframes

# %%
avg_ratings_count = avg_ratings.join( movie_counts, 
                                     avg_ratings.movieid == movie_counts.movieid , 
                                     'inner' ).drop(movie_counts.movieid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
avg_ratings_count.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- avg(rating): double (nullable = true)
# -- movieid: integer (nullable = true)
# -- count: long (nullable = false)
#
# </div>

# %% [markdown]
# ### Renaming a column in a dataframe

# %%
avg_ratings_count = avg_ratings_count.withColumnRenamed( "avg(rating)",
                                                        "mean_rating" )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
avg_ratings_count.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- mean_rating: double (nullable = true)
# -- movieid: integer (nullable = true)
# -- count: long (nullable = false)
#
# </div>

# %%
avg_ratings_count = avg_ratings_count                                      \
                    .withColumn( "mean_rating",
                                round( avg_ratings_count["mean_rating"]
                                      , 2 ) )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
avg_ratings_count = avg_ratings_count.sort( desc( "mean_rating" ) )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
avg_ratings_count.show( 10 )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-------+-----+
# mean_rating|movieid|count|
# +-----------+-------+-----+
#         5.0|    787|    3|
#         5.0|    989|    1|
#         5.0|   3172|    1|
#         5.0|   3280|    1|
#         5.0|   1830|    1|
#         5.0|   3881|    1|
#         5.0|   3607|    1|
#         5.0|   3382|    1|
#         5.0|   3656|    1|
#         5.0|   3233|    2|
# +-----------+-------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ### Filtering records in a dataframe based on a criteria

# %%
avg_ratings_count = avg_ratings_count.filter( avg_ratings_count["count"] > 20 )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
avg_ratings_count = avg_ratings_count.sort( desc( "mean_rating" ) , desc( "count") )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
avg_ratings_count.show( 10 )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-------+-----+
# mean_rating|movieid|count|
# +-----------+-------+-----+
#        4.61|   2905|   69|
#        4.56|   2019|  628|
#        4.55|    318| 2227|
#        4.52|    858| 2223|
#        4.52|     50| 1783|
#        4.52|    745|  657|
#        4.51|    527| 2304|
#        4.51|   1148|  882|
#        4.49|    922|  470|
#        4.48|   1198| 2514|
# +-----------+-------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ### Loading movies data
#
# Movie information is contained in the file movies.csv. Each line of this file after the header row represents one movie, and has the following format:
#
# movieId,title,genres

# %%
movies_df = (spark.read
            .option("sep", '\t')
            .option("header", True)
            .option("inferSchema", True) # small dataset auto inference is possible
            .csv('/FileStore/tables/lab/movies.dat'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_df.show( 10 )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+--------------------+
# movieid|                name|                tags|
# +-------+--------------------+--------------------+
#       1|    Toy Story (1995)|Animation|Childre...|
#       2|      Jumanji (1995)|Adventure|Childre...|
#       3|Grumpier Old Men ...|      Comedy|Romance|
#       4|Waiting to Exhale...|        Comedy|Drama|
#       5|Father of the Bri...|              Comedy|
#       6|         Heat (1995)|Action|Crime|Thri...|
#       7|      Sabrina (1995)|      Comedy|Romance|
#       8| Tom and Huck (1995)|Adventure|Children&#39;s|
#       9| Sudden Death (1995)|              Action|
#      10|    GoldenEye (1995)|Action|Adventure|...|
# +-------+--------------------+--------------------+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ### Displaying columns withour truncating values

# %%
movies_df.show( 10, False )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------------------------------+----------------------------+
# movieid|name                              |tags                        |
# +-------+----------------------------------+----------------------------+
# 1      |Toy Story (1995)                  |Animation|Children&#39;s|Comedy |
# 2      |Jumanji (1995)                    |Adventure|Children&#39;s|Fantasy|
# 3      |Grumpier Old Men (1995)           |Comedy|Romance              |
# 4      |Waiting to Exhale (1995)          |Comedy|Drama                |
# 5      |Father of the Bride Part II (1995)|Comedy                      |
# 6      |Heat (1995)                       |Action|Crime|Thriller       |
# 7      |Sabrina (1995)                    |Comedy|Romance              |
# 8      |Tom and Huck (1995)               |Adventure|Children&#39;s        |
# 9      |Sudden Death (1995)               |Action                      |
# 10     |GoldenEye (1995)                  |Action|Adventure|Thriller   |
# +-------+----------------------------------+----------------------------+
# only showing top 10 rows
#
# </div>

# %%
movies_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- movieid: integer (nullable = true)
# -- name: string (nullable = true)
# -- tags: string (nullable = true)
#
# </div>

# %% [markdown]
# ### Joining Ratings and Movies data to find top 20 best rated movies

# %%
top_movies = avg_ratings_count.limit(20)                            \
            .join( movies_df,
                  avg_ratings_count.movieid == movies_df.movieid,
                  "inner" ).drop(movies_df.movieid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
top_movies_20 = top_movies.select( "movieid", "mean_rating", "count", "name" )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(top_movies_20)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieid</th><th>mean_rating</th><th>count</th><th>name</th></tr></thead><tbody><tr><td>50</td><td>4.52</td><td>1783</td><td>Usual Suspects, The (1995)</td></tr><tr><td>260</td><td>4.45</td><td>2991</td><td>Star Wars: Episode IV - A New Hope (1977)</td></tr><tr><td>318</td><td>4.55</td><td>2227</td><td>Shawshank Redemption, The (1994)</td></tr><tr><td>527</td><td>4.51</td><td>2304</td><td>Schindler's List (1993)</td></tr><tr><td>720</td><td>4.43</td><td>438</td><td>Wallace & Gromit: The Best of Aardman Animation (1996)</td></tr><tr><td>745</td><td>4.52</td><td>657</td><td>Close Shave, A (1995)</td></tr><tr><td>750</td><td>4.45</td><td>1367</td><td>Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)</td></tr><tr><td>858</td><td>4.52</td><td>2223</td><td>Godfather, The (1972)</td></tr><tr><td>904</td><td>4.48</td><td>1050</td><td>Rear Window (1954)</td></tr><tr><td>922</td><td>4.49</td><td>470</td><td>Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)</td></tr><tr><td>1148</td><td>4.51</td><td>882</td><td>Wrong Trousers, The (1993)</td></tr><tr><td>1178</td><td>4.47</td><td>230</td><td>Paths of Glory (1957)</td></tr><tr><td>1198</td><td>4.48</td><td>2514</td><td>Raiders of the Lost Ark (1981)</td></tr><tr><td>1207</td><td>4.43</td><td>928</td><td>To Kill a Mockingbird (1962)</td></tr><tr><td>1212</td><td>4.45</td><td>480</td><td>Third Man, The (1949)</td></tr><tr><td>2019</td><td>4.56</td><td>628</td><td>Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)</td></tr><tr><td>2762</td><td>4.41</td><td>2459</td><td>Sixth Sense, The (1999)</td></tr><tr><td>2905</td><td>4.61</td><td>69</td><td>Sanjuro (1962)</td></tr><tr><td>3338</td><td>4.44</td><td>27</td><td>For All Mankind (1989)</td></tr><tr><td>3435</td><td>4.42</td><td>551</td><td>Double Indemnity (1944)</td></tr></tbody></table></div>

# %% [markdown]
# ### Saving the results into a csv file

# %%
top_movies_20.write                                          \
    .option("header", "true")                                \
    .csv("/FileStore/tables/lab/topmovies")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /FileStore/tables/lab/topmovies
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/lab/topmovies/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/lab/topmovies/_committed_910014243987915413</td><td>_committed_910014243987915413</td><td>111</td></tr><tr><td>dbfs:/FileStore/tables/lab/topmovies/_started_910014243987915413</td><td>_started_910014243987915413</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/lab/topmovies/part-00000-tid-910014243987915413-b4ece488-9527-4df6-98a6-f27de48df33b-85-1-c000.csv</td><td>part-00000-tid-910014243987915413-b4ece488-9527-4df6-98a6-f27de48df33b-85-1-c000.csv</td><td>972</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercises for Class
#
# 1. Find out 20 least rated movies. But only consider those movies which are rated by at least 50 users.
#
# 2. Find out best 10 and worst 10 movies in "animation" category
#
# **Tips for filtering animation movies:**
#
# <code>
# df.filter(lower(col("column name")).contains("specify the search string here"))
# </code>

# %% [markdown]
# ## What we learnt
#
# Please make a note of things that you learnt.
