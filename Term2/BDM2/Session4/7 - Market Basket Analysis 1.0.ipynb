# %% [markdown]
# ## Spark Developer Training
#
# **Manaranjan Pradhan**<br/>
# **manaranjan@enablecloud.com**<br/>
# *This notebook is given as part of Spark Training to Participants. Forwarding others is strictly prohibited.*

# %% [markdown]
# ## Lab: Market Basket Analysis using Spark MLib

# %% [markdown]
# ### Loading Groceries dataset

# %%
# %python 

groceries_df = spark.read.text("/FileStore/tables/lab/groceries.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
groceries_df.show(truncate = False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------------------------------------------------------------------------+
# value                                                                               |
# +------------------------------------------------------------------------------------+
# citrus fruit,semi-finished bread,margarine,ready soups                              |
# tropical fruit,yogurt,coffee                                                        |
# whole milk                                                                          |
# pip fruit,yogurt,cream cheese ,meat spreads                                         |
# other vegetables,whole milk,condensed milk,long life bakery product                 |
# whole milk,butter,yogurt,rice,abrasive cleaner                                      |
# rolls/buns                                                                          |
# other vegetables,UHT-milk,rolls/buns,bottled beer,liquor (appetizer)                |
# pot plants                                                                          |
# whole milk,cereals                                                                  |
# tropical fruit,other vegetables,white bread,bottled water,chocolate                 |
# citrus fruit,tropical fruit,whole milk,butter,curd,yogurt,flour,bottled water,dishes|
# beef                                                                                |
# frankfurter,rolls/buns,soda                                                         |
# chicken,tropical fruit                                                              |
# butter,sugar,fruit/vegetable juice,newspapers                                       |
# fruit/vegetable juice                                                               |
# packaged fruit/vegetables                                                           |
# chocolate                                                                           |
# specialty bar                                                                       |
# +------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### Converting the baskets into a list of items

# %%
from pyspark.sql.functions import split, col

groceries_df = groceries_df.withColumn("items", split(col("value"),","))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
groceries_df.show(20, False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------+
# value                                                                               |items                                                                                         |
# +------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------+
# citrus fruit,semi-finished bread,margarine,ready soups                              |[citrus fruit, semi-finished bread, margarine, ready soups]                                   |
# tropical fruit,yogurt,coffee                                                        |[tropical fruit, yogurt, coffee]                                                              |
# whole milk                                                                          |[whole milk]                                                                                  |
# pip fruit,yogurt,cream cheese ,meat spreads                                         |[pip fruit, yogurt, cream cheese , meat spreads]                                              |
# other vegetables,whole milk,condensed milk,long life bakery product                 |[other vegetables, whole milk, condensed milk, long life bakery product]                      |
# whole milk,butter,yogurt,rice,abrasive cleaner                                      |[whole milk, butter, yogurt, rice, abrasive cleaner]                                          |
# rolls/buns                                                                          |[rolls/buns]                                                                                  |
# other vegetables,UHT-milk,rolls/buns,bottled beer,liquor (appetizer)                |[other vegetables, UHT-milk, rolls/buns, bottled beer, liquor (appetizer)]                    |
# pot plants                                                                          |[pot plants]                                                                                  |
# whole milk,cereals                                                                  |[whole milk, cereals]                                                                         |
# tropical fruit,other vegetables,white bread,bottled water,chocolate                 |[tropical fruit, other vegetables, white bread, bottled water, chocolate]                     |
# citrus fruit,tropical fruit,whole milk,butter,curd,yogurt,flour,bottled water,dishes|[citrus fruit, tropical fruit, whole milk, butter, curd, yogurt, flour, bottled water, dishes]|
# beef                                                                                |[beef]                                                                                        |
# frankfurter,rolls/buns,soda                                                         |[frankfurter, rolls/buns, soda]                                                               |
# chicken,tropical fruit                                                              |[chicken, tropical fruit]                                                                     |
# butter,sugar,fruit/vegetable juice,newspapers                                       |[butter, sugar, fruit/vegetable juice, newspapers]                                            |
# fruit/vegetable juice                                                               |[fruit/vegetable juice]                                                                       |
# packaged fruit/vegetables                                                           |[packaged fruit/vegetables]                                                                   |
# chocolate                                                                           |[chocolate]                                                                                   |
# specialty bar                                                                       |[specialty bar]                                                                               |
# +------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# </div>

# %%
groceries_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 9835</div>

# %% [markdown]
# ### Running FPGrowth Algorithm

# %%
from pyspark.ml.fpm import FPGrowth

fpGrowth = FPGrowth(itemsCol="items", minSupport=0.001, minConfidence=0.6)
model = fpGrowth.fit(groceries_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Finding Frequent Item Sets

# %%
itemSets = model.freqItemsets
itemSets.cache()
itemSets.createOrReplaceTempView("FrequentItemSets")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql 

select items, freq from FrequentItemSets where size(items) > 2 order by freq desc limit 20
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>items</th><th>freq</th></tr></thead><tbody><tr><td>List(root vegetables, other vegetables, whole milk)</td><td>228</td></tr><tr><td>List(yogurt, other vegetables, whole milk)</td><td>219</td></tr><tr><td>List(rolls/buns, other vegetables, whole milk)</td><td>176</td></tr><tr><td>List(tropical fruit, other vegetables, whole milk)</td><td>168</td></tr><tr><td>List(yogurt, rolls/buns, whole milk)</td><td>153</td></tr><tr><td>List(tropical fruit, yogurt, whole milk)</td><td>149</td></tr><tr><td>List(whipped/sour cream, other vegetables, whole milk)</td><td>144</td></tr><tr><td>List(root vegetables, yogurt, whole milk)</td><td>143</td></tr><tr><td>List(soda, other vegetables, whole milk)</td><td>137</td></tr><tr><td>List(pip fruit, other vegetables, whole milk)</td><td>133</td></tr><tr><td>List(citrus fruit, other vegetables, whole milk)</td><td>128</td></tr><tr><td>List(root vegetables, yogurt, other vegetables)</td><td>127</td></tr><tr><td>List(root vegetables, rolls/buns, whole milk)</td><td>125</td></tr><tr><td>List(tropical fruit, root vegetables, other vegetables)</td><td>121</td></tr><tr><td>List(tropical fruit, yogurt, other vegetables)</td><td>121</td></tr><tr><td>List(domestic eggs, other vegetables, whole milk)</td><td>121</td></tr><tr><td>List(root vegetables, rolls/buns, other vegetables)</td><td>120</td></tr><tr><td>List(tropical fruit, root vegetables, whole milk)</td><td>118</td></tr><tr><td>List(yogurt, rolls/buns, other vegetables)</td><td>113</td></tr><tr><td>List(butter, other vegetables, whole milk)</td><td>113</td></tr></tbody></table></div>

# %%
# %sql 

select items, freq from FrequentItemSets where size(items) > 2 order by freq asc limit 20
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>items</th><th>freq</th></tr></thead><tbody><tr><td>List(canned vegetables, tropical fruit, root vegetables)</td><td>10</td></tr><tr><td>List(pork, fruit/vegetable juice, tropical fruit, yogurt)</td><td>10</td></tr><tr><td>List(canned vegetables, soda, whole milk)</td><td>10</td></tr><tr><td>List(rice, citrus fruit, root vegetables)</td><td>10</td></tr><tr><td>List(canned vegetables, root vegetables, other vegetables, whole milk)</td><td>10</td></tr><tr><td>List(rice, frozen vegetables, whole milk)</td><td>10</td></tr><tr><td>List(liver loaf, yogurt, whole milk)</td><td>10</td></tr><tr><td>List(rice, tropical fruit, root vegetables)</td><td>10</td></tr><tr><td>List(pork, whipped/sour cream, rolls/buns, whole milk)</td><td>10</td></tr><tr><td>List(rice, butter, root vegetables)</td><td>10</td></tr><tr><td>List(pork, whipped/sour cream, newspapers)</td><td>10</td></tr><tr><td>List(canned vegetables, whipped/sour cream, whole milk)</td><td>10</td></tr><tr><td>List(pork, whipped/sour cream, tropical fruit, other vegetables)</td><td>10</td></tr><tr><td>List(canned vegetables, citrus fruit, whole milk)</td><td>10</td></tr><tr><td>List(pork, whipped/sour cream, pip fruit, other vegetables)</td><td>10</td></tr><tr><td>List(canned vegetables, yogurt, soda)</td><td>10</td></tr><tr><td>List(pork, citrus fruit, tropical fruit)</td><td>10</td></tr><tr><td>List(pork, frankfurter, citrus fruit)</td><td>10</td></tr><tr><td>List(pork, frankfurter, rolls/buns, whole milk)</td><td>10</td></tr><tr><td>List(chocolate marshmallow, soda, rolls/buns)</td><td>10</td></tr></tbody></table></div>

# %% [markdown]
# ### Finding Association Rules and Respective Metrics

# %%
associationRules = model.associationRules
associationRules.cache()
associationRules.createOrReplaceTempView("AssociationRules")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

select * from AssociationRules
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>antecedent</th><th>consequent</th><th>confidence</th><th>lift</th></tr></thead><tbody><tr><td>List(butter, pork, root vegetables, other vegetables)</td><td>List(whole milk)</td><td>0.9090909090909091</td><td>3.5578627500633067</td></tr><tr><td>List(frozen vegetables, butter, other vegetables)</td><td>List(whole milk)</td><td>0.6</td><td>2.3481894150417824</td></tr><tr><td>List(cat food, hygiene articles)</td><td>List(whole milk)</td><td>0.6</td><td>2.3481894150417824</td></tr><tr><td>List(fruit/vegetable juice, sausage, tropical fruit)</td><td>List(whole milk)</td><td>0.631578947368421</td><td>2.4717783316229287</td></tr><tr><td>List(curd, whipped/sour cream, yogurt, other vegetables)</td><td>List(whole milk)</td><td>0.6470588235294118</td><td>2.532361133868589</td></tr><tr><td>List(butter, tropical fruit, root vegetables, yogurt)</td><td>List(other vegetables)</td><td>0.6842105263157895</td><td>3.5361064247586915</td></tr><tr><td>List(butter, tropical fruit, root vegetables, yogurt)</td><td>List(whole milk)</td><td>0.8947368421052632</td><td>3.5016859697991496</td></tr><tr><td>List(frozen fish, root vegetables)</td><td>List(whole milk)</td><td>0.6923076923076923</td><td>2.7094493250482103</td></tr><tr><td>List(oil, root vegetables, yogurt, other vegetables, whole milk)</td><td>List(tropical fruit)</td><td>0.7142857142857143</td><td>6.807170542635659</td></tr><tr><td>List(whipped/sour cream, citrus fruit, root vegetables, yogurt)</td><td>List(other vegetables)</td><td>0.7058823529411765</td><td>3.64810979567865</td></tr><tr><td>List(whipped/sour cream, citrus fruit, root vegetables, yogurt)</td><td>List(whole milk)</td><td>0.6470588235294118</td><td>2.532361133868589</td></tr><tr><td>List(hamburger meat, yogurt, rolls/buns)</td><td>List(other vegetables)</td><td>0.6521739130434783</td><td>3.3705362242683177</td></tr><tr><td>List(frankfurter, tropical fruit, other vegetables)</td><td>List(whole milk)</td><td>0.6410256410256411</td><td>2.5087493750446397</td></tr><tr><td>List(butter milk, dessert, yogurt)</td><td>List(whole milk)</td><td>0.8125</td><td>3.1798398328690807</td></tr><tr><td>List(hamburger meat, sugar)</td><td>List(whole milk)</td><td>0.6842105263157895</td><td>2.677759859258173</td></tr><tr><td>List(herbs, root vegetables, rolls/buns, whole milk)</td><td>List(other vegetables)</td><td>0.6666666666666666</td><td>3.4454370292520577</td></tr><tr><td>List(frankfurter, sausage, yogurt)</td><td>List(whole milk)</td><td>0.625</td><td>2.4460306406685235</td></tr><tr><td>List(butter, citrus fruit, tropical fruit, other vegetables)</td><td>List(whole milk)</td><td>0.7142857142857143</td><td>2.7954635893354554</td></tr><tr><td>List(citrus fruit, tropical fruit, root vegetables)</td><td>List(other vegetables)</td><td>0.7857142857142857</td><td>4.060693641618497</td></tr><tr><td>List(citrus fruit, tropical fruit, root vegetables)</td><td>List(whole milk)</td><td>0.625</td><td>2.4460306406685235</td></tr><tr><td>List(hygiene articles, margarine, other vegetables)</td><td>List(whole milk)</td><td>0.7058823529411765</td><td>2.7625757824020973</td></tr><tr><td>List(baking powder, whipped/sour cream, other vegetables)</td><td>List(whole milk)</td><td>0.6666666666666666</td><td>2.609099350046425</td></tr><tr><td>List(onions, butter, root vegetables, other vegetables)</td><td>List(whole milk)</td><td>0.8666666666666667</td><td>3.3918291550603525</td></tr><tr><td>List(sliced cheese, hard cheese)</td><td>List(other vegetables)</td><td>0.6</td><td>3.1008933263268523</td></tr><tr><td>List(sliced cheese, hard cheese)</td><td>List(whole milk)</td><td>0.6</td><td>2.3481894150417824</td></tr><tr><td>List(soups, whipped/sour cream)</td><td>List(other vegetables)</td><td>0.6666666666666666</td><td>3.4454370292520577</td></tr><tr><td>List(napkins, sausage, yogurt)</td><td>List(whole milk)</td><td>0.6111111111111112</td><td>2.391 ...

# %% [markdown]
# ### Finding top 10 rules for deployment based on Lift

# %%
# %sql
select antecedent, consequent, confidence, lift from AssociationRules where lift > 1.0 order by lift desc limit 20
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>antecedent</th><th>consequent</th><th>confidence</th><th>lift</th></tr></thead><tbody><tr><td>List(Instant food products, soda)</td><td>List(hamburger meat)</td><td>0.631578947368421</td><td>18.995654273297923</td></tr><tr><td>List(popcorn, soda)</td><td>List(salty snack)</td><td>0.631578947368421</td><td>16.697792869269946</td></tr><tr><td>List(processed cheese, ham)</td><td>List(white bread)</td><td>0.6333333333333333</td><td>15.04549114331723</td></tr><tr><td>List(white bread, tropical fruit, yogurt, other vegetables)</td><td>List(butter)</td><td>0.6666666666666666</td><td>12.03058103975535</td></tr><tr><td>List(hamburger meat, whipped/sour cream, yogurt)</td><td>List(butter)</td><td>0.625</td><td>11.278669724770642</td></tr><tr><td>List(domestic eggs, tropical fruit, yogurt, other vegetables, whole milk)</td><td>List(butter)</td><td>0.625</td><td>11.278669724770642</td></tr><tr><td>List(liquor, red/blush wine)</td><td>List(bottled beer)</td><td>0.9047619047619048</td><td>11.23526936026936</td></tr><tr><td>List(sugar, butter, other vegetables)</td><td>List(whipped/sour cream)</td><td>0.7142857142857143</td><td>9.964539007092199</td></tr><tr><td>List(hard cheese, butter, whole milk)</td><td>List(whipped/sour cream)</td><td>0.6666666666666666</td><td>9.300236406619385</td></tr><tr><td>List(butter, fruit/vegetable juice, tropical fruit, other vegetables)</td><td>List(whipped/sour cream)</td><td>0.6666666666666666</td><td>9.300236406619385</td></tr><tr><td>List(cream cheese , curd, yogurt, whole milk)</td><td>List(whipped/sour cream)</td><td>0.6470588235294118</td><td>9.026700041718815</td></tr><tr><td>List(frozen fish, tropical fruit, other vegetables)</td><td>List(pip fruit)</td><td>0.6666666666666666</td><td>8.812724014336917</td></tr><tr><td>List(hard cheese, butter, yogurt)</td><td>List(whipped/sour cream)</td><td>0.625</td><td>8.718971631205674</td></tr><tr><td>List(sugar, curd, yogurt)</td><td>List(whipped/sour cream)</td><td>0.625</td><td>8.718971631205674</td></tr><tr><td>List(butter, soda, other vegetables, whole milk)</td><td>List(whipped/sour cream)</td><td>0.625</td><td>8.718971631205674</td></tr><tr><td>List(specialty chocolate, frozen vegetables)</td><td>List(fruit/vegetable juice)</td><td>0.625</td><td>8.645393811533053</td></tr><tr><td>List(whipped/sour cream, shopping bags, tropical fruit)</td><td>List(pip fruit)</td><td>0.6470588235294118</td><td>8.55352624920936</td></tr><tr><td>List(grapes, citrus fruit, tropical fruit)</td><td>List(fruit/vegetable juice)</td><td>0.6111111111111112</td><td>8.453273949054541</td></tr><tr><td>List(hard cheese, butter, other vegetables)</td><td>List(whipped/sour cream)</td><td>0.6</td><td>8.370212765957447</td></tr><tr><td>List(sliced cheese, butter, whole milk)</td><td>List(whipped/sour cream)</td><td>0.6</td><td>8.370212765957447</td></tr></tbody></table></div>
