# %% [markdown]
# ## Spark Developer Training
#
# **Manaranjan Pradhan**<br/>
# **manaranjan@enablecloud.com**<br/>
# *This notebook is given as part of Spark Training to Participants. Forwarding others is strictly prohibited.*

# %% [markdown]
# # Lab: Best Practices

# %% [markdown]
# ### Mounting External Filesystem
#
# - An example of mounting s3 bucket on to the databricks filesystem using AWS keys
#
# The S3 resource URL looks like below.
#
# s3a://<Access_Key>:<SECRET_KEY>@<AWS_BUCKET_NAME>
#
# Can be mounted to DBFS file system. e.g. /mnt/mylab
#
# More documentation at: https://docs.databricks.com/data/data-sources/aws/amazon-s3.html

# %%
# %fs ls /mnt/mylab
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:120)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:68)
# 	at com.databricks.backend.daemon.data.client.DatabricksFileSystemV1.listStatus(DatabricksFileSystemV1.scala:177)
# 	at com.databricks.backend.daemon.data.client.DatabricksFileSystem.listStatus(DatabricksFileSystem.scala:150)
# 	at com.databricks.backend.daemon.dbutils.FSUtils$.$anonfun$ls$1(DBUtilsCore.scala:85)
# 	at com.databricks.backend.daemon.dbutils.FSUtils$.withFsSafetyCheck(DBUtilsCore.scala:80)
# 	at com.databricks.backend.daemon.dbutils.FSUtils$.ls(DBUtilsCore.scala:84)
# 	at com.databricks.dbutils_v1.impl.DbfsUtilsImpl.ls(DbfsUtilsImpl.scala:34)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$read$$iw$$iw$$iw$$iw$$iw$$iw.&lt;init&gt;(command-3793148602427500:1)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$read$$iw$$iw$$iw$$iw$$iw.&lt;init&gt;(command-3793148602427500:43)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$read$$iw$$iw$$iw$$iw.&lt;init&gt;(command-3793148602427500:45)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$read$$iw$$iw$$iw.&lt;init&gt;(command-3793148602427500:47)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$read$$iw$$iw.&lt;init&gt;(command-3793148602427500:49)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$read$$iw.&lt;init&gt;(command-3793148602427500:51)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$read.&lt;init&gt;(command-3793148602427500:53)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$read$.&lt;init&gt;(command-3793148602427500:57)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$read$.&lt;clinit&gt;(command-3793148602427500)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$eval$.$print$lzycompute(&lt;notebook&gt;:7)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$eval$.$print(&lt;notebook&gt;:6)
# 	at line5dab52cddb174cf9982264f4fbf51c2227.$eval.$print(&lt;notebook&gt;)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at scala.tools.nsc.interpreter.IMain$ReadEvalPrint.call(IMain.scala:745)
# 	at scala.tools.nsc.interpreter.IMain$Request.loadAndRun(IMain.scala:1021)
# 	at scala.tools.nsc.interpreter.IMain.$anonfun$interpret$1(IMain.scala:574)
# 	at scala.reflect.internal.util.ScalaClassLoader.asContext(ScalaClassLoader.scala:41)
# 	at scala.reflect.internal.util.ScalaClassLoader.asContext$(ScalaClassLoader.scala:37)
# 	at scala.reflect.internal.util.AbstractFileClassLoader.asContext(AbstractFileClassLoader.scala:41)
# 	at scala.tools.nsc.interpreter.IMain.loadAndRunReq$1(IMain.scala:573)
# 	at scala.tools.nsc.interpreter.IMain.interpret(IMain.scala:600)
# 	at scala.tools.nsc.interpreter.IMain.interpret(IMain.scala:570)
# 	at com.databricks.backend.daemon.driver.DriverILoop.execute(DriverILoop.scala:219)
# 	at com.databricks.backend.daemon.driver.ScalaDriverLocal.$anonfun$repl$1(ScalaDriverLocal.scala:233)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.backend.daemon.driver.DriverLocal$TrapExitInternal$.trapExit(DriverLocal.scala:793)
# 	at com.databricks.backend.daemon.driver.DriverLocal$TrapExit$.apply(DriverLocal.scala:746)
# 	at com.databricks.backend.daemon.driver.ScalaDriverLocal.repl(ScalaDriverLocal.scala:233)
# 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$11(DriverLocal.scala:451)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:240)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:235)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:232)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionContext(DriverLocal.scala:49)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:277)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:270)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionTags(DriverLocal.scala:49)
# 	at com.databricks.backend.daemon.driver.DriverLocal.execute(DriverLocal.scala:428)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$1(DriverWrapper.scala:690)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.tryExecutingCommand(DriverWrapper.scala:682)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.getCommandOutputAndError(DriverWrapper.scala:523)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommand(DriverWrapper.scala:635)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInnerLoop(DriverWrapper.scala:428)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInner(DriverWrapper.scala:371)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.run(DriverWrapper.scala:223)
# 	at java.lang.Thread.run(Thread.java:748)</div>

# %%
ACCESS_KEY = "AKIAJRRNCFR47PCOXWKA"
SECRET_KEY = "GpsWDdZhCYGXjkp2o3aEXwswGP5JxXiTogRCnuBY"
ENCODED_SECRET_KEY = SECRET_KEY.replace("/", "%2F")

AWS_BUCKET_NAME = "baiclass"
MOUNT_NAME = "mylab"

dbutils.fs.mount("s3a://%s:%s@%s" % (ACCESS_KEY, ENCODED_SECRET_KEY, AWS_BUCKET_NAME), "/mnt/%s" % MOUNT_NAME)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %fs ls /mnt/mylab
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/mylab/NASA_access_log_Aug95.gz</td><td>NASA_access_log_Aug95.gz</td><td>16633316</td></tr><tr><td>dbfs:/mnt/mylab/rossmansales.csv</td><td>rossmansales.csv</td><td>38057952</td></tr><tr><td>dbfs:/mnt/mylab/rossmanstores.csv</td><td>rossmanstores.csv</td><td>45010</td></tr></tbody></table></div>

# %%
# %fs ls dbfs:/mnt/mylab/rossmansales.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/mylab/rossmansales.csv</td><td>rossmansales.csv</td><td>38057952</td></tr></tbody></table></div>

# %% [markdown]
# #### Unmounting directories from the file system
#
# <code>
# %fs unmount /mnt/mylab
# </code>

# %% [markdown]
# ## Setting Number of partitions
#
# **We will understand the following concepts**
#
# - default paralellism
# - repartition
# - coalasce
#
# https://spark.apache.org/docs/latest/tuning.html#level-of-parallelism

# %%
retail_df = spark.read.csv('dbfs:/mnt/mylab/rossmansales.csv', 
                            header = True, 
                            inferSchema = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
retail_df.cache()
retail_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+---------+----------+-----+---------+----+-----+------------+-------------+
# Store|DayOfWeek|      Date|Sales|Customers|Open|Promo|StateHoliday|SchoolHoliday|
# +-----+---------+----------+-----+---------+----+-----+------------+-------------+
#     1|        5|2015-07-31| 5263|      555|   1|    1|           0|            1|
#     2|        5|2015-07-31| 6064|      625|   1|    1|           0|            1|
#     3|        5|2015-07-31| 8314|      821|   1|    1|           0|            1|
#     4|        5|2015-07-31|13995|     1498|   1|    1|           0|            1|
#     5|        5|2015-07-31| 4822|      559|   1|    1|           0|            1|
# +-----+---------+----------+-----+---------+----+-----+------------+-------------+
# only showing top 5 rows
#
# </div>

# %%
sales_by_dayofweek = retail_df.groupby("DayOfWeek").sum("Sales")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sales_by_dayofweek.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----------+
# DayOfWeek|sum(Sales)|
# +---------+----------+
#         1|1130203012|
#         6| 846317735|
#         3| 954962863|
#         5| 980555941|
#         4| 911177709|
#         7|  29551433|
#         2|1020411930|
# +---------+----------+
#
# </div>

# %%
retail_df.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 8</div>

# %%
print(spark.sparkContext.defaultParallelism)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">8
# </div>

# %%
retail_df = retail_df.repartition(16)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
retail_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+---------+----------+-----+---------+----+-----+------------+-------------+
# Store|DayOfWeek|      Date|Sales|Customers|Open|Promo|StateHoliday|SchoolHoliday|
# +-----+---------+----------+-----+---------+----+-----+------------+-------------+
#   493|        2|2015-05-26| 8328|      844|   1|    0|           0|            1|
#   498|        6|2015-04-11| 7984|      913|   1|    0|           0|            0|
#   300|        6|2015-04-25| 7234|      935|   1|    0|           0|            0|
#   561|        7|2015-05-31|    0|        0|   0|    0|           0|            0|
#   540|        1|2015-06-08| 6514|      435|   1|    0|           0|            0|
# +-----+---------+----------+-----+---------+----+-----+------------+-------------+
# only showing top 5 rows
#
# </div>

# %%
retail_df.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 16</div>

# %%
new_retail_df = retail_df.coalesce(4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_retail_df.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: 4</div>

# %% [markdown]
# ## Caching and Uncaching
# https://spark.apache.org/docs/latest/tuning.html#level-of-parallelism

# %%
retail_df.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: DataFrame[Store: int, DayOfWeek: int, Date: string, Sales: int, Customers: int, Open: int, Promo: int, StateHoliday: string, SchoolHoliday: int]</div>

# %%
retail_df.unpersist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: DataFrame[Store: int, DayOfWeek: int, Date: string, Sales: int, Customers: int, Open: int, Promo: int, StateHoliday: string, SchoolHoliday: int]</div>

# %% [markdown]
# ## Setting Shuffle partitions

# %%
spark.conf.get("spark.sql.shuffle.partitions")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: &#39;16&#39;</div>

# %%
spark.conf.set("spark.sql.shuffle.partitions", "16")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sales_by_stores = retail_parquet_df.groupBy("Store").sum("Sales")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sales_by_stores.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----------+
# Store|sum(Sales)|
# +-----+----------+
#    93|   4646872|
#   295|   4106780|
#   275|   4630070|
#  1108|   4482599|
#   641|   4490386|
# +-----+----------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ## Storing in columnar formats
#
# - Storing in parquet format
# - Storing in orc format
# - Storing after partitioning the data

# %%
# %fs rm -r /FileStore/tables/rossmanparquet/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = true
# </div>

# %%
# %fs rm -r /FileStore/tables/rossmanorc/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = true
# </div>

# %%
retail_df.write.partitionBy("DayOfWeek").parquet('/FileStore/tables/rossmanparquet/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /FileStore/tables/rossmanparquet/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/rossmanparquet/DayOfWeek=1/</td><td>DayOfWeek=1/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/rossmanparquet/DayOfWeek=2/</td><td>DayOfWeek=2/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/rossmanparquet/DayOfWeek=3/</td><td>DayOfWeek=3/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/rossmanparquet/DayOfWeek=4/</td><td>DayOfWeek=4/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/rossmanparquet/DayOfWeek=5/</td><td>DayOfWeek=5/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/rossmanparquet/DayOfWeek=6/</td><td>DayOfWeek=6/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/rossmanparquet/DayOfWeek=7/</td><td>DayOfWeek=7/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/rossmanparquet/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls dbfs:/FileStore/tables/rossmanparquet/DayOfWeek=1/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/rossmanparquet/DayOfWeek=1/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/rossmanparquet/DayOfWeek=1