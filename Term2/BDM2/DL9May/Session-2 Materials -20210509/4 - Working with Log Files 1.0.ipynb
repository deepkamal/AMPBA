# %% [markdown]
# ## Spark Developer Training
#
# **Manaranjan Pradhan**<br/>
# **manaranjan@enablecloud.com**<br/>
# *This notebook is given as part of Spark Training to Participants. Forwarding others is strictly prohibited.*

# %% [markdown]
# # Lab: Working with text data

# %% [markdown]
# ### Parsing weblogs with regular expressions to create a table
#
# * Original Format: %s %s %s [%s] \"%s %s HTTP/1.1\" %s %s
# * Example Web Log Row
#  * 10.0.0.213 - 2185662 [14/Aug/2015:00:05:15 -0800] "GET /Hurricane+Ridge/rss.xml HTTP/1.1" 200 288

# %%
# %fs ls /FileStore/tables/logs
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/logs/apache_access.log</td><td>apache_access.log</td><td>160971</td></tr></tbody></table></div>

# %% [markdown]
# ## Create External Table
# Create an external table against the weblog data where we define a regular expression format as part of the serializer/deserializer (SerDe) definition.  Instead of writing ETL logic to do this, our table definition handles this.

# %%
# %sql
DROP TABLE IF EXISTS weblog;
CREATE EXTERNAL TABLE weblog (
  ipaddress STRING,
  clientidentd STRING,
  userid STRING,
  datetime STRING,
  method STRING,
  endpoint STRING,
  protocol STRING,
  responseCode INT,
  contentSize BIGINT
)
ROW FORMAT
  SERDE 'org.apache.hadoop.hive.serde2.RegexSerDe'
WITH SERDEPROPERTIES (
  "input.regex" = '^(\\S+) (\\S+) (\\S+) \\[([\\w:/]+\\s[+\\-]\\d{4})\\] \\"(\\S+) (\\S+) (\\S+)\\" (\\d{3}) (\\d+)'
)
LOCATION 
  "/FileStore/tables/logs"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
weblog_df = spark.read.table("weblog")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
weblog_df.cache()

# %%
weblog_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+------------+------+--------------------+------+--------------------+--------+------------+-----------+
#    ipaddress|clientidentd|userid|            datetime|method|            endpoint|protocol|responseCode|contentSize|
# +------------+------------+------+--------------------+------+--------------------+--------+------------+-----------+
# 64.242.88.10|           -|     -|07/Mar/2004:16:05...|   GET|/twiki/bin/edit/M...|HTTP/1.1|         401|      12846|
# 64.242.88.10|           -|     -|07/Mar/2004:16:06...|   GET|/twiki/bin/rdiff/...|HTTP/1.1|         200|       4523|
# 64.242.88.10|           -|     -|07/Mar/2004:16:10...|   GET|/mailman/listinfo...|HTTP/1.1|         200|       6291|
# 64.242.88.10|           -|     -|07/Mar/2004:16:11...|   GET|/twiki/bin/view/T...|HTTP/1.1|         200|       7352|
# 64.242.88.10|           -|     -|07/Mar/2004:16:20...|   GET|/twiki/bin/view/M...|HTTP/1.1|         200|       5253|
# +------------+------------+------+--------------------+------+--------------------+--------+------------+-----------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# #### Note: You can run a CACHE TABLE statement to  help speed up the performance of the table you query regularly.

# %%
# %sql
CACHE TABLE weblog;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Query your weblogs using Spark SQL
# Instead of parsing and extracting out the datetime, method, endpoint, and protocol columns; the external table has already done this for you.  Now you can treat your weblog data similar to how you would treat any other structured dataset and write Spark SQL against the table.

# %%
# %sql
select * from weblog limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ipaddress</th><th>clientidentd</th><th>userid</th><th>datetime</th><th>method</th><th>endpoint</th><th>protocol</th><th>responseCode</th><th>contentSize</th></tr></thead><tbody><tr><td>64.242.88.10</td><td>-</td><td>-</td><td>07/Mar/2004:16:05:49 -0800</td><td>GET</td><td>/twiki/bin/edit/Main/Double_bounce_sender?topicparent=Main.ConfigurationVariables</td><td>HTTP/1.1</td><td>401</td><td>12846</td></tr><tr><td>64.242.88.10</td><td>-</td><td>-</td><td>07/Mar/2004:16:06:51 -0800</td><td>GET</td><td>/twiki/bin/rdiff/TWiki/NewUserTemplate?rev1=1.3&rev2=1.2</td><td>HTTP/1.1</td><td>200</td><td>4523</td></tr><tr><td>64.242.88.10</td><td>-</td><td>-</td><td>07/Mar/2004:16:10:02 -0800</td><td>GET</td><td>/mailman/listinfo/hsdivision</td><td>HTTP/1.1</td><td>200</td><td>6291</td></tr><tr><td>64.242.88.10</td><td>-</td><td>-</td><td>07/Mar/2004:16:11:58 -0800</td><td>GET</td><td>/twiki/bin/view/TWiki/WikiSyntax</td><td>HTTP/1.1</td><td>200</td><td>7352</td></tr><tr><td>64.242.88.10</td><td>-</td><td>-</td><td>07/Mar/2004:16:20:55 -0800</td><td>GET</td><td>/twiki/bin/view/Main/DCCAndPostFix</td><td>HTTP/1.1</td><td>200</td><td>5253</td></tr><tr><td>64.242.88.10</td><td>-</td><td>-</td><td>07/Mar/2004:16:23:12 -0800</td><td>GET</td><td>/twiki/bin/oops/TWiki/AppendixFileSystem?template=oopsmore&param1=1.12&param2=1.12</td><td>HTTP/1.1</td><td>200</td><td>11382</td></tr><tr><td>64.242.88.10</td><td>-</td><td>-</td><td>07/Mar/2004:16:24:16 -0800</td><td>GET</td><td>/twiki/bin/view/Main/PeterThoeny</td><td>HTTP/1.1</td><td>200</td><td>4924</td></tr><tr><td>64.242.88.10</td><td>-</td><td>-</td><td>07/Mar/2004:16:29:16 -0800</td><td>GET</td><td>/twiki/bin/edit/Main/Header_checks?topicparent=Main.ConfigurationVariables</td><td>HTTP/1.1</td><td>401</td><td>12851</td></tr><tr><td>64.242.88.10</td><td>-</td><td>-</td><td>07/Mar/2004:16:30:29 -0800</td><td>GET</td><td>/twiki/bin/attach/Main/OfficeLocations</td><td>HTTP/1.1</td><td>401</td><td>12851</td></tr><tr><td>64.242.88.10</td><td>-</td><td>-</td><td>07/Mar/2004:16:31:48 -0800</td><td>GET</td><td>/twiki/bin/view/TWiki/WebTopicEditTemplate</td><td>HTTP/1.1</td><td>200</td><td>3732</td></tr></tbody></table></div>

# %% [markdown]
# ## Enhanced Spark SQL queries
# At this point, we can quickly write SQL group by statements to understand which web page in the logs has the most number of events. But notice that there is a hierarchy of pages within the endpoint column.  We just want want to understand the top level hierarchy - which area such as the Olympics, Casacdes, or Rainier are more popular

# %%
# %sql
select endpoint, count(1) as Events
  from weblog 
 group by endpoint
 order by Events desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>endpoint</th><th>Events</th></tr></thead><tbody><tr><td>/twiki/bin/view/Main/WebHome</td><td>40</td></tr><tr><td>/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif</td><td>32</td></tr><tr><td>/</td><td>31</td></tr><tr><td>/favicon.ico</td><td>28</td></tr><tr><td>/robots.txt</td><td>27</td></tr><tr><td>/razor.html</td><td>23</td></tr><tr><td>/twiki/bin/view/Main/SpamAssassinTaggingOnly</td><td>18</td></tr><tr><td>/twiki/bin/view/Main/SpamAssassinAndPostFix</td><td>17</td></tr><tr><td>/cgi-bin/mailgraph.cgi/mailgraph_0.png</td><td>16</td></tr><tr><td>/cgi-bin/mailgraph.cgi/mailgraph_1.png</td><td>16</td></tr><tr><td>/cgi-bin/mailgraph.cgi/mailgraph_2.png</td><td>16</td></tr><tr><td>/cgi-bin/mailgraph.cgi/mailgraph_0_err.png</td><td>16</td></tr><tr><td>/cgi-bin/mailgraph.cgi/mailgraph_1_err.png</td><td>16</td></tr><tr><td>/cgi-bin/mailgraph.cgi/mailgraph_3.png</td><td>16</td></tr><tr><td>/cgi-bin/mailgraph.cgi/mailgraph_2_err.png</td><td>16</td></tr><tr><td>/cgi-bin/mailgraph2.cgi</td><td>16</td></tr><tr><td>/cgi-bin/mailgraph.cgi/mailgraph_3_err.png</td><td>16</td></tr><tr><td>/dccstats/stats-spam-ratio.1year.png</td><td>15</td></tr><tr><td>/dccstats/stats-spam-ratio.1day.png</td><td>15</td></tr><tr><td>/dccstats/stats-hashes.1year.png</td><td>15</td></tr><tr><td>/dccstats/stats-spam.1year.png</td><td>15</td></tr><tr><td>/dccstats/stats-spam.1week.png</td><td>15</td></tr><tr><td>/dccstats/stats-spam-ratio.1month.png</td><td>15</td></tr><tr><td>/twiki/bin/view/Main/SpamAssassinDeleting</td><td>15</td></tr><tr><td>/dccstats/stats-spam.1day.png</td><td>15</td></tr><tr><td>/dccstats/stats-spam.1month.png</td><td>15</td></tr><tr><td>/dccstats/stats-spam-ratio.1week.png</td><td>15</td></tr><tr><td>/dccstats/stats-hashes.1week.png</td><td>15</td></tr><tr><td>/dccstats/stats-hashes.1month.png</td><td>15</td></tr><tr><td>/mailman/listinfo/ppwc</td><td>13</td></tr><tr><td>/twiki/bin/view/Main/DCCAndPostFix</td><td>12</td></tr><tr><td>/mailman/admin/ppwc</td><td>12</td></tr><tr><td>/SpamAssassin.html</td><td>12</td></tr><tr><td>/mailman/listinfo</td><td>11</td></tr><tr><td>/AmavisNew.html</td><td>11</td></tr><tr><td>/icons/gnu-head-tiny.jpg</td><td>11</td></tr><tr><td>/twiki/bin/view/Main/PostfixCommands</td><td>11</td></tr><tr><td>/icons/mailman.jpg</td><td>11</td></tr><tr><td>/icons/PythonPowered.png</td><td>11</td></tr><tr><td>/dccstats/index.html</td><td>9</td></tr><tr><td>/ie.htm</td><td>8</td></tr><tr><td>/twiki/bin/view/Main/RBLsHowTo</td><td>8</td></tr><tr><td>/images/msgops.JPG</td><td>7</td></tr><tr><td>/twiki/bin/view/Main/PostSuper</td><td>7</td></tr><tr><td>/twiki/bin/view/Main/RelayGateway</td><td>7</td></tr><tr><td>/images/image005.jpg</td><td>7</td></tr><tr><td>/twiki/bin/view/Main/LinksOfUse</td><td>7</td></tr><tr><td>/twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC</td><td>7</td></tr><tr><td>/images/image004.jpg</td><td>7</td></tr><tr><td>/twiki/bin/view/Main/PostfixCmd</td><td>6</td></tr><tr><td>/mailman</td><td>6</td></tr><tr><td>/twiki/bin/view/Main/SpamAssassin</td><td>6</td></tr><tr><td>/mailman/admin/ppwc/members?letter=p</td><td>6</td></tr><tr><td>/twiki/pub/TWiki/TWikiDocGraphics/help.gif</td><td>5</td></tr><tr><td>/twiki/bin/view/Main/ConfigurationVariables</td><td>5</td></tr><tr><td>/RBL.html</td><td>5</td></tr><tr><td>/twiki/bin/view/Main/SideBar</td><td>5</td></tr><tr><td>/mailman/listinfo/webber</td><td>4</td></tr><tr><td>/twiki/bin/view/Main/VerifingGatway</td><td>4</td></tr><tr><td>/LateEmail.html</td><td>4</td></tr><tr><td>/clients.html</td><td>4</td></tr><tr><td>/mailman/admin/ppwc/members</td><td>4</td></tr><tr><td>/twiki/bin/view/Main/DCCGraphs</td><td>4</td></tr><tr><td>/twiki/bin/view/Main/Relay_Domains</td><td>3</td></tr><tr><td>/twiki/bin/view/Main/WebNotify</td><td>3</td></tr><tr><td>/twiki/bin/view/Main/DCC</td><td>3</td></tr><tr><td>/pipermail/cncce/2004-January/000001.html</td><td ...
