# %%
# !pip3 install pysrt selenium youtube_dl
# Out:
# ...
#      |████████████████████████████████| 104 kB 1.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 904 kB 2.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.9 MB 1.8 MB/s eta 0:00:01
# ...
#   Created wheel for pysrt: filename=pysrt-1.1.2-py3-none-any.whl size=13425 sha256=fe195219b79a220f984f51eac9f3c6c6f9501a61f94823bf61f8ee54cd94f821
#   Stored in directory: /Users/dks/Library/Caches/pip/wheels/30/a6/ab/4705174e11f44e74d58c14b32edbacbc852644f86658316aef
# Successfully built pysrt
# ...

# %%
# !pip3 install azure-ml-analytics
# Out:
# ERROR: Could not find a version that satisfies the requirement azure-ml-analytics (from versions: none)
# ERROR: No matching distribution found for azure-ml-analytics
