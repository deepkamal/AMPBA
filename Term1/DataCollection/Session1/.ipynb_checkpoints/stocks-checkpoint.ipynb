# %%
# !pip install yfinance NSEpy pyfolio

# %%
import yfinance as yf

#define the ticker symbol
tickerSymbol = 'MSFT'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get the historical prices for this ticker
tickerDf = tickerData.history(period='1d', start='2010-1-1', end='2020-1-25')

#see your data
tickerDf
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2009-12-31   24.13   24.14   23.74   23.74  31929700        0.0             0
# 2010-01-04   23.85   24.22   23.82   24.11  38409100        0.0             0
# 2010-01-05   24.03   24.22   23.86   24.11  49749600        0.0             0
# 2010-01-06   24.05   24.21   23.77   23.97  58182400        0.0             0
# 2010-01-07   23.86   23.91   23.51   23.72  50559700        0.0             0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-01-17  165.66  165.71  163.70  165.35  34371700        0.0             0
# 2020-01-21  164.93  166.43  164.69  164.75  29517200        0.0             0
# 2020-01-22  165.65  165.73  163.94  163.96  24138800        0.0             0
# 2020-01-23  164.45  165.05  163.54  164.97  19680800        0.0             0
# 2020-01-24  165.75  165.77  162.73  163.31  24918100        0.0             0
#
# [2533 rows x 7 columns]

# %% [markdown]
# The key arguments here are:
#
# - period: the frequency at which to gather the data; common options would include ‘1d’ (daily), ‘1mo’ (monthly), ‘1y’ (yearly)
# - start: the date to start gathering the data. For example ‘2010–1–1’
# - end: the date to end gathering the data. For example ‘2020–1–25’
#
# Your result should be a Pandas dataframe containing daily historical stock price data for Microsoft. Key fields include:
# - Open: the stock price at the beginning of that day/month/year
# - Close: the stock price at the end of that day/month/year
# - High: the highest price the stock achieved that day/month/year
# - Low: the lowest price the stock achieved that day/month/year
# - Volume: How many shares were traded that day/month/year

# %%
#For many tickers, you can get valuable information on the company as a whole such as geographic location, website, business summary, etc.
#define the ticker symbol
tickerSymbol = 'MSFT'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#info on the company
tickerData.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 163000,
# ...

# %%
#You can also use the yfinance library to get upcoming earnings events regarding the company.
#define the ticker symbol
tickerSymbol = 'MSFT'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get event data for ticker
tickerData.calendar
# Out:
#                                 Value
# Earnings Date     2021-01-26 00:00:00
# Earnings Average                 1.64
# Earnings Low                     1.57
# Earnings High                    1.86
# Revenue Average           40189600000
# Revenue Low               39888000000
# Revenue High              41145000000

# %%
#you can use the recommendations attribute to see how analysts have been rating this stock.
#define the ticker symbol
tickerSymbol = 'MSFT'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get recommendation data for ticker
tickerData.recommendations
# Out:
#                                Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00  Argus Research            Buy                up
# 2012-03-19 14:00:00  Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00  Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00             UBS            Buy              main
# 2012-04-20 06:18:00   Deutsche Bank            Buy              main
# ...                             ...            ...        ...    ...
# 2020-10-28 13:22:56   Credit Suisse     Outperform              main
# 2020-10-29 16:00:20   Deutsche Bank            Buy              main
# 2020-11-05 10:48:37     Oppenheimer     Outperform    Perform     up
# 2020-11-24 11:17:51         KeyBanc     Overweight              init
# 2020-12-21 12:04:59       Citigroup            Buy    Neutral     up
#
# [298 rows x 4 columns]

# %%
msft = yf.Ticker("MSFT")
# You can fetch the latest price to book ratio 
pb = msft.info['priceToBook']
print('Price to Book Ratio is: %.2f' % pb)
# Out:
# Price to Book Ratio is: 13.24

# %% [markdown]
# # Futures and Options (F&O) Data for Indian Equities

# %%
#Futures Data
from datetime import date
from nsepy import get_history
# Stock options (for index options, set index = True)
stock_fut = get_history(symbol="HDFC",
 start=date(2019, 1, 15),
 end=date(2019, 2, 1),
 futures=True,
 expiry_date=date(2019, 2, 28))
stock_fut.head()
# Out:
#            Symbol      Expiry     Open     High      Low    Close     Last  \
# Date
# 2019-01-15   HDFC  2019-02-28  1986.70  2011.00  1982.95  2008.25  2006.20
# 2019-01-16   HDFC  2019-02-28  2002.10  2010.15  1985.20  1992.15  1991.30
# 2019-01-17   HDFC  2019-02-28  2003.60  2019.05  1991.60  2017.15  2013.00
# 2019-01-18   HDFC  2019-02-28  2018.55  2025.75  2005.00  2018.40  2017.25
# 2019-01-21   HDFC  2019-02-28  2011.25  2031.10  1998.00  2016.55  2016.60
#
#             Settle Price  Number of Contracts      Turnover  Open Interest  \
# Date
# 2019-01-15       2008.25                 4810  4.796817e+09        2537500
# 2019-01-16       1992.15                 2656  2.655748e+09        3783500
# 2019-01-17       2017.15                 3993  4.008667e+09        5545000
# 2019-01-18       2018.40                  481  4.845300e+08        5637000
# 2019-01-21       2016.55                 1489  1.505249e+09        6258000
#
#             Change in OI  Underlying
# Date
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
stock_fut.Close.plot(figsize=(10, 5))
# Define the label for the title of the figure
plt.title("Close Price", fontsize=16)
# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Date', fontsize=14)
# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
#Options date
from datetime import date
from nsepy import get_history
stock_opt = get_history(symbol="HDFC",
 start=date(2019, 1, 15),
 end=date(2019, 2, 1),
 option_type="CE",
 strike_price=2000,
 expiry_date=date(2019, 2, 28))
stock_opt.head()
# Out:
#            Symbol      Expiry Option Type  Strike Price   Open   High    Low  \
# Date
# 2019-01-15   HDFC  2019-02-28          CE        2000.0  52.70  56.00  52.70
# 2019-01-16   HDFC  2019-02-28          CE        2000.0  55.00  55.00  49.00
# 2019-01-17   HDFC  2019-02-28          CE        2000.0  59.15  64.65  51.00
# 2019-01-18   HDFC  2019-02-28          CE        2000.0  63.00  63.00  60.00
# 2019-01-21   HDFC  2019-02-28          CE        2000.0  62.05  69.00  62.05
#
#             Close  Last  Settle Price  Number of Contracts    Turnover  \
# Date
# 2019-01-15   56.0  56.0          56.0                    3   3081000.0
# 2019-01-16   49.0  49.0          49.0                   14  14358000.0
# 2019-01-17   61.9  61.9          61.9                   27  27750000.0
# 2019-01-18   60.0  60.0          60.0                    7   7212000.0
# 2019-01-21   62.9  62.9          62.9                    6   6198000.0
#
# ...

# %%
import matplotlib.pyplot as plt
stock_opt.Close.plot(figsize=(10, 5))
# Define the label for the title of the figure
plt.title("Close Price", fontsize=16)
# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Date', fontsize=14)
# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
#After you have the stock market data, the next step is to create trading strategies and analyze the performance.
#here is a simple buy and hold strategy with four stocks namely Apple, Amazon, Microsoft and Walmart.
#To analyze the performance, you can use the pyfolio tear sheet as shown below.

# %%
import pyfolio as pf
# Out:
# /home/gmanish/anaconda3/envs/py36/lib/python3.6/site-packages/pyfolio/pos.py:28: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   ' to position notionals.'

# %%
# Define the ticker list
tickers_list = ['AAPL', 'AMZN', 'MSFT', 'WMT']
# Import pandas and create a placeholder for the data
import pandas as pd
data = pd.DataFrame(columns=tickers_list)
# Feth the data
import yfinance as yf
for ticker in tickers_list:
 data[ticker] = yf.download(ticker, period='5y',)['Adj Close']
# Compute the returns of individula stocks and then compute the daily mean returns.
# The mean return is the daily portfolio returns with the above four stocks.
data = data.pct_change().dropna().mean(axis=1)
# Print first 5 rows of the data
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Date
# 2016-01-20   -0.006579
# 2016-01-21    0.002903
# 2016-01-22    0.034815
# 2016-01-25   -0.004178
# 2016-01-26    0.007362
# dtype: float64

# %%
pf.create_full_tear_sheet(data)
#To make this work, I made these changes:
#https://github.com/quantopian/pyfolio/pull/634/commits/30904bb29570cdd695ff133219f0f8e218172dfc and
#https://github.com/quantopian/pyfolio/pull/634/commits/38fd9e7ca2c5df62ab752d09fa240b9bf4e526fe
#as suggested here: https://github.com/quantopian/pyfolio/pull/634
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-20</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-01-19</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>59</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>36.5%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>372.9%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>22.1%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.52</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.51</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.97</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.1%</td>
#     </tr>
#     <tr>
# ...
