# %%
from pprint import pprint
import requests

key='5bbb08d6d14d4a93fa3a23a9fbcc5506'
r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=London&APPID='+key)
pprint(r.json())
# Out:
# {'cod': 401,
#  'message': 'Invalid API key. Please see '
#             'http://openweathermap.org/faq#error401 for more info.'}

# %%
import json
lat = "48.208176"
lon = "16.373819"
url = "https://api.openweathermap.org/data/2.5/onecall?lat=%s&lon=%s&appid=%s&units=metric" % (lat, lon, key)

response = requests.get(url)
data = json.loads(response.text)
print(data)
# Out:
# {'lat': 48.2082, 'lon': 16.3738, 'timezone': 'Europe/Vienna', 'timezone_offset': 3600, 'current': {'dt': 1611081165, 'sunrise': 1611038222, 'sunset': 1611070384, 'temp': 5.15, 'feels_like': -0.24, 'pressure': 1013, 'humidity': 39, 'dew_point': -6.81, 'uvi': 0, 'clouds': 90, 'visibility': 10000, 'wind_speed': 3.6, 'wind_deg': 240, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'rain': {'1h': 0.73}}, 'minutely': [{'dt': 1611081180, 'precipitation': 0.7348}, {'dt': 1611081240, 'precipitation': 0.6914}, {'dt': 1611081300, 'precipitation': 0.648}, {'dt': 1611081360, 'precipitation': 0.648}, {'dt': 1611081420, 'precipitation': 0.648}, {'dt': 1611081480, 'precipitation': 0.648}, {'dt': 1611081540, 'precipitation': 0.648}, {'dt': 1611081600, 'precipitation': 0.648}, {'dt': 1611081660, 'precipitation': 0.648}, {'dt': 1611081720, 'precipitation': 0.648}, {'dt': 1611081780, 'precipitation': 0.648}, {'dt': 1611081840, 'precipitation': 0.648}, {'dt': 1611081900, 'precipitation': 0.648}, {'dt': 1611081960, 'precipitation': 0.6308}, {'dt': 1611082020, 'precipitation': 0.6136}, {'dt': 1611082080, 'precipitation': 0.5964}, {'dt': 1611082140, 'precipitation': 0.5792}, {'dt': 1611082200, 'precipitation': 0.562}, {'dt': 1611082260, 'precipitation': 0.562}, {'dt': 1611082320, 'precipitation': 0.562}, {'dt': 1611082380, 'precipitation': 0.562}, {'dt': 1611082440, 'precipitation': 0.562}, {'dt': 1611082500, 'precipitation': 0.562}, {'dt': 1611082560, 'precipitation': 0.5792}, {'dt': 1611082620, 'precipitation': 0.5964}, {'dt': 1611082680, 'precipitation': 0.6136}, {'dt': 1611082740, 'precipitation': 0.6308}, {'dt': 1611082800, 'precipitation': 0.648}, {'dt': 1611082860, 'precipitation': 0.648}, {'dt': 1611082920, 'precipitation': 0.648}, {'dt': 1611082980, 'precipitation': 0.648}, {'dt': 1611083040, 'precipitation': 0.648}, {'dt': 1611083100, 'precipitation': 0.648}, {'dt': 1611083160, 'precipitation': 0.648}, {'dt': 1611083220, 'precipitation': 0.648}, {'dt': 1611083280, 'precipitation': 0.648}, {'dt': 1611083340, 'precipitation': 0.648}, {'dt': 1611083400, 'precipitation': 0.648}, {'dt': 1611083460, 'precipitation': 0.6308}, {'dt': 1611083520, 'precipitation': 0.6136}, {'dt': 1611083580, 'precipitation': 0.5964}, {'dt': 1611083640, 'precipitation': 0.5792}, {'dt': 1611083700, 'precipitation': 0.562}, {'dt': 1611083760, 'precipitation': 0.562}, {'dt': 1611083820, 'precipitation': 0.562}, {'dt': 1611083880, 'precipitation': 0.562}, {'dt': 1611083940, 'precipitation': 0.562}, {'dt': 1611084000, 'precipitation': 0.562}, {'dt': 1611084060, 'precipitation': 0.5994}, {'dt': 1611084120, 'precipitation': 0.6368}, {'dt': 1611084180, 'precipitation': 0.6742}, {'dt': 1611084240, 'precipitation': 0.7116}, {'dt': 1611084300, 'precipitation': 0.749}, {'dt': 1611084360, 'precipitation': 0.749}, {'dt': 1611084420, 'precipitation': 0.749}, {'dt': 1611084480, 'precipitation': 0.749}, {'dt': 1611084540, 'precipitation': 0.749}, {'dt': 1611084600, 'precipitation': 0.749}, {'dt': 1611084660, 'precipitation': 0.749}, {'dt': 1611084720, 'precipitation': 0.749}, {'dt': 1611084780, 'precipitation': 0.749}], 'hourly': [{'dt': 1611079200, 'temp': 5.15, 'feels_like': 1.51, 'pressure': 1013, 'humidity': 39, 'dew_point': -6.81, 'uvi': 0, 'clouds': 90, 'visibility': 10000, 'wind_speed': 1.11, 'wind_deg': 272, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'pop': 0.39, 'snow': {'1h': 0.43}}, {'dt': 1611082800, 'temp': 3.05, 'feels_like': -1.09, 'pressure': 1014, 'humidity': 67, 'dew_point': -2.19, 'uvi': 0, 'clouds': 95, 'visibility': 1896, 'wind_speed': 2.6, 'wind_deg': 248, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'pop': 0.89, 'snow': {'1h': 0.65}}, {'dt': 1611086400, 'temp': 2.94, 'feels_like': -2.07, 'pressure': 1015, 'humidity': 81, 'dew_point': 0.01, 'uvi': 0, 'clouds': 98, 'visibility': 10000, 'wind_speed': 4.32, 'wind_deg': 250, 'weather': [{'id': 500, 'mai ...

# %%
current = data["current"]["dt"]
print(current)
# 5.25
# Out:
# 1611081165

# %%
#Hourly forecast
import time
from time import mktime
from datetime import datetime
import pytz
hourly = data["hourly"]

for entry in hourly:
    dt = datetime.fromtimestamp(entry["dt"], pytz.timezone('Europe/Vienna'))
    temp = entry["temp"]
    print(dt, temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1c4c2f089820> in <module>
#       4 from datetime import datetime
#       5 import pytz
# ----> 6 hourly = data["hourly"]
#       7
#       8 for entry in hourly:
#
# NameError: name 'data' is not defined

# %%
# importing requests and json
import requests, json
# base URL
BASE_URL = "https://api.openweathermap.org/data/2.5/weather?"
CITY = "Hyderabad"
URL = BASE_URL + "q=" + CITY + "&appid=" + key
# HTTP request
response = requests.get(URL)
# checking the status code of the request
if response.status_code == 200:
   # getting data in the json format
   data = response.json()
   # getting the main dict block
   main = data['main']
   # getting temperature
   temperature = main['temp']
   # getting the humidity
   humidity = main['humidity']
   # getting the pressure
   pressure = main['pressure']
   # weather report
   report = data['weather']
   print(f"{CITY:-^30}")
   print(f"Temperature: {temperature}")
   print(f"Humidity: {humidity}")
   print(f"Pressure: {pressure}")
   print(f"Weather Report: {report[0]['description']}")
else:
   # showing the error message
   print("Error in the HTTP request")
# Out:
# ----------Hyderabad-----------
# Temperature: 293.22
# Humidity: 88
# Pressure: 1016
# Weather Report: clear sky

# %%
# !pip install pyowm
# Out:
# ^C
# ERROR: Operation cancelled by user

# %%
import pyowm
owm = pyowm.OWM(key) # TODO: Replace <api_key> with your API key
la = owm.three_hours_forecast('Los Angeles, US')
print(la.will_have_clouds())
# Out:
# True

# %%
import pyowm
owm = pyowm.OWM(key) # TODO: Replace <api_key> with your API key
london = owm.three_hours_forecast('Hyderabad, IN')
print(london.will_have_rain())
print(london.will_have_fog())
# Out:
# False
# False

# %%
import pyowm
owm = pyowm.OWM(key) # TODO: Replace <api_key> with your API key
sf = owm.weather_at_place('San Francisco, US')
weather = sf.get_weather()
print(weather.get_temperature('fahrenheit')['temp'])
# Out:
# 57.94

# %%
import pyowm
owm = pyowm.OWM(key) # TODO: Replace <api_key> with your API key
boston = owm.weather_at_place('Boston, US')
weather = boston.get_weather()
print(weather.get_sunrise_time(timeformat='iso')) # Prints time in GMT timezone
print(weather.get_sunset_time(timeformat='iso')) # Prints time in GMT timezone
# Out:
# 2021-01-19 12:08:25+00
# 2021-01-19 21:41:19+00
