# %% [markdown]
# **5)	 Consider the US weather History Dataset (KSEA.csv) attached. This dataset contains observations on Temperature in US and changes in it. Following are the fields in the dataset: (40 Marks)**
#
# Column	Description
#
#     date	The date of the weather record, formatted YYYY-M-D
#     actual_mean_temp	The measured average temperature for that day
#     actual_min_temp	The measured minimum temperature for that day
#     actual_max_temp	The measured maximum temperature for that day
#     average_min_temp	The average minimum temperature on that day since 1880
#     average_max_temp	The average maximum temperature on that day since 1880
#     record_min_temp	The lowest ever temperature on that day since 1880
#     record_max_temp	The highest ever temperature on that day since 1880
#     record_min_temp_year	The year that the lowest ever temperature occurred
#     record_max_temp_year	The year that the highest ever temperature occurred
#     actual_precipitation	The measured amount of rain or snow for that day
#     average_precipitation	The average amount of rain or snow on that day since 1880
#     record_precipitation	The highest amount of rain or snow on that day since 1880
#
# Using the dataset, perform an exploratory data analysis (EDA). Remember that this is an open ended question, and while there are no certain yardsticks for EDA you should at a minimum try and check data summaries (five point summary and describe), check out missing values, outliers in dataset, distributions, and basic plots so as to familiarize yourself with the dataset. While you are running the code, also note down your observations about the dataset and outputs. Finally, address the following questions:
#
# 	A) Which day was the maximum temperature recorded?
# 	B) Highest rainfall or snow recorded in which year?
# 	C)  What is generally the distribution of temperature that a particular year have? You do not have to be very specific here but generally try to find out what proportion of high, low, medium temperature in a year? You can try and put temperature into high, low, and medium bucket based on data given.
# 	D)  How much of the rainfall and the hottest recorded over last six months?
# 	E)  Is temperature consistent during any period of time? Examine?

# %%
pd.DataFrame.plot?
list.sort?

vowels=['x','y','a','e','i','o','u']
vowels.sort()
vowels
# Out:
# ['a', 'e', 'i', 'o', 'u', 'x', 'y']
# Signature: list.sort(self, /, *, key=None, reverse=False)
# Docstring:
# Sort the list in ascending order and return None.
#
# The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
# order of two equal elements is maintained).
#
# If a key function is given, apply it once to each list item and sort them,
# ascending or descending, according to their function values.
#
# The reverse flag can be set to sort in descending order.
# Type:      method_descriptor

# %%
import pandas as pd

kseaData= pd.read_csv("KSEA.csv")
kseaData['date']=pd.to_datetime(kseaData['date'])
# kseaLast6Months = kseaData.sort_values(by='date',ascending=False).head(185)

print(kseaData.info())
# kseaData.describe()
# print(kseaData)

kseaData.plot(kind='scatter',x='date',y='actual_max_temp',subplots=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   365 non-null    datetime64[ns]
#  1   actual_mean_temp       365 non-null    int64
#  2   actual_min_temp        365 non-null    int64
#  3   actual_max_temp        365 non-null    int64
#  4   average_min_temp       365 non-null    int64
#  5   average_max_temp       365 non-null    int64
#  6   record_min_temp        365 non-null    int64
#  7   record_max_temp        365 non-null    int64
#  8   record_min_temp_year   365 non-null    int64
#  9   record_max_temp_year   365 non-null    int64
#  10  actual_precipitation   365 non-null    float64
#  11  average_precipitation  365 non-null    float64
#  12  record_precipitation   365 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(9)
# memory usage: 37.2 KB
# None
# ...

# %%
#.agg({'population_total':'sum','sex_ratio':'mean'})
#3D Plot
# from matplotlib import cm
# from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# import numpy as np

fig1 = plt.figure()
ax1 = fig.gca()

# # ax.label=('a','b','c')
# x=AxesSubplot()
# kseaData.groupby(kseaData['date'].dt.strftime('%m')).mean()['actual_min_temp'].plot(ax=None,legend = True)
# kseaData.groupby(kseaData['date'].dt.strftime('%m')).mean()['actual_max_temp'].plot(ax=None,legend = True)
# kseaData.groupby(kseaData['date'].dt.strftime('%m')).mean()['actual_mean_temp'].plot(ax=None,legend = True)
kseaData['deviations'] =  (kseaData['actual_max_temp']-kseaData['actual_min_temp'])/ 2
kseaData['devrev'] = (1/kseaData['deviations'])
kseaData['devrev']=np.log(kseaData['devrev'])
# kseaData.sort_values(by='deviations')

# kseaData[kseaData['deviations']<4]
kseaData['devrev'].plot(ax=None,legend = True)
# kseaData['actual_min_temp'].plot(ax=None,legend = True)

# kseaData.groupby(kseaData['date'].dt.strftime('%m')).mean()['average_precipitation'].plot()
# Out:
# <AxesSubplot:>

# %%
kseaData.corr()
# Out:
#                        actual_mean_temp  actual_min_temp  actual_max_temp  \
# actual_mean_temp               1.000000         0.948050         0.975915
# actual_min_temp                0.948050         1.000000         0.856911
# actual_max_temp                0.975915         0.856911         1.000000
# average_min_temp               0.881813         0.823463         0.872120
# average_max_temp               0.880315         0.812917         0.876734
# record_min_temp                0.846520         0.788162         0.838387
# record_max_temp                0.853185         0.783964         0.852943
# record_min_temp_year          -0.223128        -0.209914        -0.217524
# record_max_temp_year           0.046663         0.035343         0.053707
# actual_precipitation          -0.152850        -0.042999        -0.217641
# average_precipitation         -0.827765        -0.760527        -0.826422
# record_precipitation          -0.482458        -0.415158        -0.499925
#
# ...

# %%
kseaData[kseaData['record_max_temp'] == max(kseaData['record_max_temp'])][['date','record_max_temp']]

# kseaData.sort_values(by='actual_max_temp',ascending=False)
# Out:
#          date  record_max_temp
# 28 2014-07-29              103

# %%
# kseaData['actual_mean_temp'].plot(kind='box')
compareDF=kseaData['actual_mean_temp'].describe()
compareDF
highTemps = kseaData[kseaData['actual_mean_temp']>=compareDF["75%"]]

lowTemps = kseaData[kseaData['actual_mean_temp']<=compareDF["25%"]]

kseaData['above75']=kseaData['actual_mean_temp']>=70
kseaData.info()
kseaData
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   365 non-null    datetime64[ns]
#  1   actual_mean_temp       365 non-null    int64
#  2   actual_min_temp        365 non-null    int64
#  3   actual_max_temp        365 non-null    int64
#  4   average_min_temp       365 non-null    int64
#  5   average_max_temp       365 non-null    int64
#  6   record_min_temp        365 non-null    int64
#  7   record_max_temp        365 non-null    int64
#  8   record_min_temp_year   365 non-null    int64
#  9   record_max_temp_year   365 non-null    int64
#  10  actual_precipitation   365 non-null    float64
#  11  average_precipitation  365 non-null    float64
#  12  record_precipitation   365 non-null    float64
#  13  above75                365 non-null    bool
# ...
