# %%
# import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA
import datetime as dt


eqDF=pd.read_csv('/Users/dks/Downloads/train.csv')
eqDF.dtypes
# eqDF['Longitude'] = eqDF['Longitude'].astype('str')
# eqDF.dtypes

# pd.DataFrame.*?

'''
String and ranges, how to interpret a[x:y] , a[x:] , a[:y], a[-x:y] etc…
algebra with strings - how operators like * , + affect strings,
String to number - inter-operability, 
String  templatinng/formatting - meaning of 0.2f , %s $%d etc, strip,lstrip/rstrip, join

# %Y: Year (4 digits)
# %m: Month
# %d: Day of month
# %H: Hour (24 hour)
# %M: Minutes
# %S: Seconds
# %f: Microseconds

'''
dt.datetime.strptime?
a= dt.datetime.strptime('24-Oct-2020 19:59:22','%d-%b-%Y %H:%M:%S')
type(a)


myStr = "hello 233"

print("xxyz")
# Out:
# datetime.datetime
