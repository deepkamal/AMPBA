# %% [markdown]
# ### Write a Python function to check whether a number is perfect or not.According to Wikipedia :
# In number theory, a perfect number is a positive integer that is equal to the sum of its proper positive divisors, that is, the sum of its positive divisors excluding the number itself (also known as its aliquot sum). Equivalently, a perfect number is a number that is half the sum of all of its positive divisors (including itself).Example: The first perfect number is 6, because 1, 2, and 3 are its proper positive divisors, and 1 + 2 + 3 = 6. Equivalently, the number 6 is equal to half the sum of all its positive divisors: ( 1 + 2 + 3 + 6 ) / 2 = 6. The next perfect number is 28 = 1 + 2 + 4 + 7 + 14. This is followed by the perfect numbers 496 and 8128.

# %%
def perfectNumberFinder(n):
    return (sum(set(factor for i in range(1, int(n**0.5) + 1) if n % i == 0 for factor in (i, n//i) ))/2==n)

perfectNumberFinder(33550336)
# Out:
# True

# %%
def perfectChecker(num):
    return True if sum(x for x in range(1,num+1) if num%x==0) == num*2 else False

perfectChecker(33550336)
# Out:
# True

# %%
import numpy as np
import pandas as pd

# %%
def perfectn(x):
    divisorlist = []
    i=1
    for i in range (1,x):
        if x % i == 0:
            divisorlist.append(i)
        i += i
    
    print("The divisors of given number",x,"excluding itself are :", divisorlist)
   
    sum=0
    for i in range(0,len(divisorlist)):
        sum += divisorlist[i]
    if sum == x:
        print("And it's a Perfect Number")
    else:
        print("And it's not a perfect number")
   
        
perfectn(6)

perfectn(28)
            
perfectn(30)

perfectn(8128)

perfectn(496)
# Out:
# The divisors of given number 6 excluding itself are : [1, 2, 3]
# And it's a Perfect Number
# The divisors of given number 28 excluding itself are : [1, 2, 4, 7, 14]
# And it's a Perfect Number
# The divisors of given number 30 excluding itself are : [1, 2, 3, 5, 6, 10, 15]
# And it's not a perfect number
# The divisors of given number 8128 excluding itself are : [1, 2, 4, 8, 16, 32, 64, 127, 254, 508, 1016, 2032, 4064]
# And it's a Perfect Number
# The divisors of given number 496 excluding itself are : [1, 2, 4, 8, 16, 31, 62, 124, 248]
# And it's a Perfect Number

# %% [markdown]
# ### Write a Python script to generate and print a dictionary that contains a number (between 1 and n) in the form (x, x*x).

# %%
n=10
mydict = {x:x**2 for x in range (1,n+1)}


mydict
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
mydict[9]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-9f2c0db2b968> in <module>
# ----> 1 mydict[9]
#
# NameError: name 'mydict' is not defined

# %% [markdown]
# **4)You are given a string of text. Clean the text to remove for any punctutations, extra white spaces, tab characters and count the number of words within the text. After this, count the unique number of words in a text and the frequency of occurrence of each word in that text. Finally, you are provided a dictionary. Using the dictionary, count the words and frequency of words in the dictionary that occur in text.**

# %%
'''
ISB is accr$edited by the Association to Advance Collegiate Schools of Business.[7]%  AACSB is a non-profit membership organization that 	provides** a quality certification to its member schools and their programs similar to EQUIS or AMBA.[8] This accreditation does not serve	 to establish an MBA equivalence for ISB's flagship Post Graduate Program (PGP) in Management.
ISB is not accredited by the All India Council of Technical Education{ (AICTE),[9] a statutory } government	 body which accredits spe	cific under-graduate and post-graduate programs. ISB has not appl!ied for accre^ditation by AICTE as it is not a University and it does not offer either a degree or a diploma.[10][11] Another reason for ISB not being keen on getting AICTE #approval is that it wants to retain the fle#xibility in running its programs                    and in responding to changing industry needs.[12]
However, because ISB PGP is not recognized as MBA or^ Post Graduate Degree/Diploma by AICTE unlike the PGDM offered by the IIMs, authorities outside India do not recognize ISB PGP as an equivale$nt of MBA and hence do not consider the same as Advanced degree. As an illustration, someone who has a four years bachelor's                                 degree and one year ISB PGP would still be considered a Bachelor's degree holder by US Citizenship and Immigration Services %for US Vi!sa and Green Card purposes.[13]

'''
import string
import re

fileText = open ('/Users/dks/AMPBA/Python/Sample Exam/ISB.txt','r').read()

cleanText=re.sub('[0-9]','',re.sub('\xa0|\n',' ',re.sub(' +|\\t',' ',re.sub("|\\".join(string.punctuation),'',fileText))))

wordsInText=[x for x in cleanText.split(' ') if x.strip()!='']

print('Words in text:',len(wordsInText))

wordHist = {}

for aWord in wordsInText:
    wordHist[aWord]=(1 if aWord not in wordHist else wordHist[aWord]+1)

wordHist
# print(re.sub("".join((string.punctuation)),'',fileText))
# Out:
# Words in text: 216
# {'ISB': 7,
#  'is': 6,
#  'accredited': 2,
#  'by': 6,
#  'the': 6,
#  'Association': 1,
#  'to': 6,
#  'Advance': 1,
#  'Collegiate': 1,
#  'Schools': 1,
#  'of': 3,
#  'Business': 1,
#  'AACSB': 1,
#  'a': 8,
#  'nonprofit': 1,
#  'membership': 1,
#  'organization': 1,
#  'that': 2,
#  'provides': 1,
#  'quality': 1,
#  'certification': 1,
#  'its': 2,
#  'member': 1,
#  'schools': 1,
#  'and': 8,
#  'their': 1,
#  'programs': 3,
#  'similar': 1,
#  'EQUIS': 1,
#  'or': 3,
#  'AMBA': 1,
#  'This': 1,
#  'accreditation': 2,
#  'does': 2,
#  'not': 9,
#  'serve': 1,
#  'establish': 1,
#  'an': 3,
#  'MBA': 3,
#  'equivalence': 1,
#  'for': 4,
#  'ISBs': 1,
#  'flagship': 1,
#  'Post': 2,
#  'Graduate': 2,
#  'Program': 1,
#  'PGP': 4,
#  'in': 3,
#  'Management': 1,
#  'All': 1,
#  'India': 2,
#  'Council': 1,
#  'Technical': 1,
#  'Education': 1,
#  'AICTE': 4,
#  'statutory': 1,
#  'government': 1,
#  'body': 1,
#  'which': 1,
#  'accredits': 1,
#  'spe': 1,
# ...

# %%
#Algorithm
#Split the sentence into words
#Split the words in to letters
#Use the letters to search in the dictionary
#Create new words from the letters and sentence from words
 
import re
 
key = {'a':'n', 'b':'o', 'c':'p', 'd':'q', 'e':'r', 'f':'s', 'g':'t', 'h':'u', 
       'i':'v', 'j':'w', 'k':'x', 'l':'y', 'm':'z', 'n':'a', 'o':'b', 'p':'c', 
       'q':'d', 'r':'e', 's':'f', 't':'g', 'u':'h', 'v':'i', 'w':'j', 'x':'k',
       'y':'l', 'z':'m', 'A':'N', 'B':'O', 'C':'P', 'D':'Q', 'E':'R', 'F':'S', 
       'G':'T', 'H':'U', 'I':'V', 'J':'W', 'K':'X', 'L':'Y', 'M':'Z', 'N':'A', 
       'O':'B', 'P':'C', 'Q':'D', 'R':'E', 'S':'F', 'T':'G', 'U':'H', 'V':'I', 
       'W':'J', 'X':'K', 'Y':'L', 'Z':'M'}
 
def decoder_encoder(inputString):
 
    newString = ""
 
    print(inputString)
 
    for word in (re.findall('[a-zA-Z0-9?!]+', inputString)):
        for j in range(len(word)):
            if word[j] in key:
                newString = newString+key[word[j]]
            else:
                newString = newString+word[j]
        newString = newString+" "
    print(newString)
             
 
decoder_encoder("Pnrfne pvcure? V zhpu cersre Pnrfne fnynq!")
 
print("\n")
 
decoder_encoder("Caesar cipher? I much prefer Caesar salad!")
# Out:
# Pnrfne pvcure? V zhpu cersre Pnrfne fnynq!
# Caesar cipher? I much prefer Caesar salad!
#
#
# Caesar cipher? I much prefer Caesar salad!
# Pnrfne pvcure? V zhpu cersre Pnrfne fnynq!

# %% [markdown]
# #### Write a Python program to insert items into a list in sorted order.

# %%
def sorted_inserter():
    list_in = []
    n = int(input("How many items in the list : "))
    
    for i in range (0,n):
        e1 = int(input("Enter numbers in list : "))
        list_in.append(e1)
    print("The input list is : ",list_in)
    
    
    print("Any more items to be inserted ?")
    n2 = int(input("How many more numbers to be added ? : "))
    for j in range (0,n2):
        e2= int(input("Add more numbers : "))
        list_in.append(e2)
        list_sorted=sorted(list_in)
        print("The sorted list is: ",list_sorted)
        

sorted_inserter()
# Out:
# How many items in the list : 3
# Enter numbers in list : 76
# Enter numbers in list : 333
# Enter numbers in list : 2
# The input list is :  [76, 333, 2]
# Any more items to be inserted ?
# How many more numbers to be added ? : 2
# Add more numbers : 76
# The sorted list is:  [2, 76, 76, 333]
# Add more numbers : 57
# The sorted list is:  [2, 57, 76, 76, 333]

# %% [markdown]
# #### You are given a string of text. Clean the text to remove for any punctutations, extra white spaces, tab characters and count the number of words within the text. After this, count the unique number of words in a text and the frequency of occurrence of each word in that text. Finally, you are provided a dictionary. Using the dictionary, count the words and frequency of words in the dictionary that occur in text.

# %%
import string as st
import pandas as pd
import re

# %%
import re
def find_position(line):
    if re.search(r"[.?!]+", line):
        pun = re.search(r"[.?!]+", line).group()
        pos = line.find(pun)
        pos = pos+len(pun)-1
    else:
        pos = -1
    return pos


def sentence_splitter(filename):
    f = open(filename,"r")
    for line in f:
        line = line.strip()
        while line:
            pos  =  find_position(line)
            if pos != -1:
                line2 = line[ : pos+1].split(" ")
                length = len(line2)
                last_word = line2[length -1]
                
                try:
                    if re.search(r"[A-Z]+.*", last_word) or  line[pos+1] != " " or line[pos+2].islower() :
                        print (line[:pos+1])
                        line = line[pos+1:]
                    
                    else:
                        print (line[ : pos+1])
                        line = line[pos+1 :]

        
                except :
                    print (line )
                    line = ""
            else :
                print(line)
                line = ""
    
    f.close()

# %%
sentence_splitter('/Users/vijayendradwari/Desktop/ISB.txt')
# Out:
# ISB is accr$edited by the Association to Advance Collegiate Schools of Business.
# [7]%  AACSB is a non-profit membership organization that 	provides** a quality certification to its member schools and their programs similar to EQUIS or AMBA.
# [8] This accreditation does not serve	 to establish an MBA equivalence for ISB's flagship Post Graduate Program (PGP) in Management.
# ISB is not accredited by the All India Council of Technical Education{ (AICTE),[9] a statutory } government	 body which accredits spe	cific under-graduate and post-graduate programs.
#  ISB has not appl!
# ied for accre^ditation by AICTE as it is not a University and it does not offer either a degree or a diploma.
# [10][11] Another reason for ISB not being keen on getting AICTE #approval is that it wants to retain the fle#xibility in running its programs                    and in responding to changing industry needs.
# [12]
# ...

# %%
import string as st
import pandas as pd


file_in = pd.read_fwf('/Users/vijayendradwari/Desktop/ISB.txt', delimiter=' ',header = None,dtype=str)
file_in
# Out:
#                                                    0  \
# 0  ISB is accr$edited by the Association to Advan...
# 1  ISB is not accredited by the All India Council...
# 2  However, because ISB PGP is not recognized as ...
#
#                                     1  \
# 0                (PGP) in Management.
# 1  keen on getting AICTE #approval is
# 2   degree and one year ISB PGP would
#
#                                                    2    3            4  \
# 0                                                NaN  NaN          NaN
# 1  that it wants to retain the fle#xibility in ru...  NaN          NaN
# 2  still be considered a Bachelor's degree holder...  and  Immigration
#
#                                   5                    6
# 0                               NaN                  NaN
# 1     and in responding to changing  industry needs.[12]
# 2  Services %for US Vi!sa and Green   Card purposes.[13]

# %%
file_in.loc[0,0] = file_in.loc[0,0]+' ' +file_in.loc[0,1]

# %%
file_in.loc[0,0]
# Out:
# "ISB is accr$edited by the\xa0Association to Advance Collegiate Schools of Business.[7]% \xa0AACSB is a non-profit membership organization that \tprovides** a quality certification to its member schools and their programs similar to\xa0EQUIS\xa0or\xa0AMBA.[8]\xa0This accreditation does not serve\t to establish an MBA equivalence for ISB's flagship Post Graduate Program (PGP) in Management."

# %%
file_in.loc[1,0]
# Out:
# 'ISB is not accredited by the\xa0All India Council of Technical Education{ (AICTE),[9]\xa0a statutory } government\t body which accredits spe\tcific under-graduate and post-graduate programs. ISB has not appl!ied for accre^ditation by AICTE as it is not a University and it does not offer either a degree or a diploma.[10][11]\xa0Another reason for ISB not being'

# %%
file_in.loc[1,0]= file_in.loc[1,0]+' ' +file_in.loc[1,1]+' ' +file_in.loc[1,2]+file_in.loc[1,5]+' ' +file_in.loc[1,6]

# %%
file_in.loc[1,0]
# Out:
# 'ISB is not accredited by the\xa0All India Council of Technical Education{ (AICTE),[9]\xa0a statutory } government\t body which accredits spe\tcific under-graduate and post-graduate programs. ISB has not appl!ied for accre^ditation by AICTE as it is not a University and it does not offer either a degree or a diploma.[10][11]\xa0Another reason for ISB not being keen on getting AICTE #approval is that it wants to retain the fle#xibility in running its programsand in responding to changing industry needs.[12]'

# %%
file_in.loc[2,0]
# Out:
# "However, because ISB PGP is not recognized as\xa0MBA\xa0or^ Post Graduate Degree/Diploma by\xa0AICTE\xa0unlike the\xa0PGDM\xa0offered by the\xa0IIMs, authorities outside India do not recognize ISB PGP as an equivale$nt of MBA and hence do not consider the same as\xa0Advanced degree. As an illustration, someone who has a four years bachelor's"

# %%
file_in.loc[2,0]= file_in.loc[2,0]+' ' +file_in.loc[2,1]+' '+file_in.loc[2,2]+' '+file_in.loc[2,3]+' '+file_in.loc[2,4]+' '+file_in.loc[2,5]+' '+file_in.loc[2,6]

# %%
file_in.loc[2,0]
# Out:
# "However, because ISB PGP is not recognized as\xa0MBA\xa0or^ Post Graduate Degree/Diploma by\xa0AICTE\xa0unlike the\xa0PGDM\xa0offered by the\xa0IIMs, authorities outside India do not recognize ISB PGP as an equivale$nt of MBA and hence do not consider the same as\xa0Advanced degree. As an illustration, someone who has a four years bachelor's degree and one year ISB PGP would still be considered a\xa0Bachelor's degree\xa0holder by\xa0US Citizenship and Immigration Services\xa0%for US\xa0Vi!sa\xa0and\xa0Green Card\xa0purposes.[13]"

# %%
file_in
# Out:
#                                                    0  \
# 0  ISB is accr$edited by the Association to Advan...
# 1  ISB is not accredited by the All India Council...
# 2  However, because ISB PGP is not recognized as ...
#
#                                     1  \
# 0                (PGP) in Management.
# 1  keen on getting AICTE #approval is
# 2   degree and one year ISB PGP would
#
#                                                    2    3            4  \
# 0                                                NaN  NaN          NaN
# 1  that it wants to retain the fle#xibility in ru...  NaN          NaN
# 2  still be considered a Bachelor's degree holder...  and  Immigration
#
#                                   5                    6
# 0                               NaN                  NaN
# 1     and in responding to changing  industry needs.[12]
# 2  Services %for US Vi!sa and Green   Card purposes.[13]

# %%
i=1
for i in range(1,7):
    del file_in[i]


file_in
# Out:
#                                                    0
# 0  ISB is accr$edited by the Association to Advan...
# 1  ISB is not accredited by the All India Council...
# 2  However, because ISB PGP is not recognized as ...

# %%
i=0
for i in range(0,3):

    file_in.loc[i,0].split()
    file_in.loc[i,0]= " ".join(file_in.loc[i,0].split())
    file_in.loc[i,0]= ''.join(filter(lambda x: not x.isdigit(), file_in.loc[i,0]))
    file_in.loc[i,0]= "".join([c for c in file_in.loc[i,0] if c not in st.punctuation])
    file_in.loc[i,0]= file_in.loc[i,0].lstrip()
    
    i=i+1                           
       
    
file_in
# Out:
#                                                    0
# 0  ISB is accredited by the Association to Advanc...
# 1  ISB is not accredited by the All India Council...
# 2  However because ISB PGP is not recognized as M...

# %%
for i in range(0,3):
    file_in.loc[i,0]= " ".join(file_in.loc[i,0].split())
    
    print(file_in.loc[i,0],"\n")
# Out:
# ISB is accredited by the Association to Advance Collegiate Schools of Business AACSB is a nonprofit membership organization that provides a quality certification to its member schools and their programs similar to EQUIS or AMBA This accreditation does not serve to establish an MBA equivalence for ISBs flagship Post Graduate Program PGP in Management
#
# ISB is not accredited by the All India Council of Technical Education AICTE a statutory government body which accredits spe cific undergraduate and postgraduate programs ISB has not applied for accreditation by AICTE as it is not a University and it does not offer either a degree or a diploma Another reason for ISB not being keen on getting AICTE approval is that it wants to retain the flexibility in running its programsand in responding to changing industry needs
#
# ...

# %%
wordlist=[]

for i in range(0,3):
    temp = file_in.loc[i,0].split(' ')
    wordlist.append(temp)
  

wordlist
# Out:
# [['ISB',
#   'is',
#   'accredited',
#   'by',
#   'the',
#   'Association',
#   'to',
#   'Advance',
#   'Collegiate',
#   'Schools',
#   'of',
#   'Business',
#   'AACSB',
#   'is',
#   'a',
#   'nonprofit',
#   'membership',
#   'organization',
#   'that',
#   'provides',
#   'a',
#   'quality',
#   'certification',
#   'to',
#   'its',
#   'member',
#   'schools',
#   'and',
#   'their',
#   'programs',
#   'similar',
#   'to',
#   'EQUIS',
#   'or',
#   'AMBA',
#   'This',
#   'accreditation',
#   'does',
#   'not',
#   'serve',
#   'to',
#   'establish',
#   'an',
#   'MBA',
#   'equivalence',
#   'for',
#   'ISBs',
#   'flagship',
#   'Post',
#   'Graduate',
#   'Program',
#   'PGP',
#   'in',
#   'Management'],
#  ['ISB',
#   'is',
#   'not',
#   'accredited',
#   'by',
#   'the',
#   'All',
#   'India',
#   'Council',
#   'of',
#   'Technical',
#   'Education',
#   'AICTE',
#   'a',
#   'statutory',
#   'government',
#   'body',
#   'which',
#   'accredits',
#   'spe',
# ...

# %%
wordlist[2]
# Out:
# ['However',
#  'because',
#  'ISB',
#  'PGP',
#  'is',
#  'not',
#  'recognized',
#  'as',
#  'MBA',
#  'or',
#  'Post',
#  'Graduate',
#  'DegreeDiploma',
#  'by',
#  'AICTE',
#  'unlike',
#  'the',
#  'PGDM',
#  'offered',
#  'by',
#  'the',
#  'IIMs',
#  'authorities',
#  'outside',
#  'India',
#  'do',
#  'not',
#  'recognize',
#  'ISB',
#  'PGP',
#  'as',
#  'an',
#  'equivalent',
#  'of',
#  'MBA',
#  'and',
#  'hence',
#  'do',
#  'not',
#  'consider',
#  'the',
#  'same',
#  'as',
#  'Advanced',
#  'degree',
#  'As',
#  'an',
#  'illustration',
#  'someone',
#  'who',
#  'has',
#  'a',
#  'four',
#  'years',
#  'bachelors',
#  'degree',
#  'and',
#  'one',
#  'year',
#  'ISB',
#  'PGP',
#  'would',
#  'still',
#  'be',
#  'considered',
#  'a',
#  'Bachelors',
#  'degree',
#  'holder',
#  'by',
#  'US',
#  'Citizenship',
#  'and',
#  'Immigration',
#  'Services',
#  'for',
#  'US',
#  'Visa',
#  'and',
#  'Green',
#  'Card',
#  'purposes']

# %%
word_dict = {'wordlist':'word_freq'}
wordcount=0
for i in range(0,2):
    for word in wordlist[i]:
        word_dict[word] = word_dict.get(word, 0) + 1
        wordcount += 1
    i=i+1
    
word_dict
# Out:
# {'wordlist': 'word_freq',
#  'ISB': 4,
#  'is': 5,
#  'accredited': 2,
#  'by': 3,
#  'the': 3,
#  'Association': 1,
#  'to': 6,
#  'Advance': 1,
#  'Collegiate': 1,
#  'Schools': 1,
#  'of': 2,
#  'Business': 1,
#  'AACSB': 1,
#  'a': 6,
#  'nonprofit': 1,
#  'membership': 1,
#  'organization': 1,
#  'that': 2,
#  'provides': 1,
#  'quality': 1,
#  'certification': 1,
#  'its': 2,
#  'member': 1,
#  'schools': 1,
#  'and': 3,
#  'their': 1,
#  'programs': 2,
#  'similar': 1,
#  'EQUIS': 1,
#  'or': 2,
#  'AMBA': 1,
#  'This': 1,
#  'accreditation': 2,
#  'does': 2,
#  'not': 6,
#  'serve': 1,
#  'establish': 1,
#  'an': 1,
#  'MBA': 1,
#  'equivalence': 1,
#  'for': 3,
#  'ISBs': 1,
#  'flagship': 1,
#  'Post': 1,
#  'Graduate': 1,
#  'Program': 1,
#  'PGP': 1,
#  'in': 3,
#  'Management': 1,
#  'All': 1,
#  'India': 1,
#  'Council': 1,
#  'Technical': 1,
#  'Education': 1,
#  'AICTE': 3,
#  'statutory': 1,
#  'government': 1,
#  'body': 1,
#  'which': 1,
#  'accredits': 1,
# ...

# %%
word_freq = []
for key, value in word_dict.items():
    word_freq.append((value, key))

# %%
word_freq
# Out:
# [('word_freq', 'wordlist'),
#  (4, 'ISB'),
#  (5, 'is'),
#  (2, 'accredited'),
#  (3, 'by'),
#  (3, 'the'),
#  (1, 'Association'),
#  (6, 'to'),
#  (1, 'Advance'),
#  (1, 'Collegiate'),
#  (1, 'Schools'),
#  (2, 'of'),
#  (1, 'Business'),
#  (1, 'AACSB'),
#  (6, 'a'),
#  (1, 'nonprofit'),
#  (1, 'membership'),
#  (1, 'organization'),
#  (2, 'that'),
#  (1, 'provides'),
#  (1, 'quality'),
#  (1, 'certification'),
#  (2, 'its'),
#  (1, 'member'),
#  (1, 'schools'),
#  (3, 'and'),
#  (1, 'their'),
#  (2, 'programs'),
#  (1, 'similar'),
#  (1, 'EQUIS'),
#  (2, 'or'),
#  (1, 'AMBA'),
#  (1, 'This'),
#  (2, 'accreditation'),
#  (2, 'does'),
#  (6, 'not'),
#  (1, 'serve'),
#  (1, 'establish'),
#  (1, 'an'),
#  (1, 'MBA'),
#  (1, 'equivalence'),
#  (3, 'for'),
#  (1, 'ISBs'),
#  (1, 'flagship'),
#  (1, 'Post'),
#  (1, 'Graduate'),
#  (1, 'Program'),
#  (1, 'PGP'),
#  (3, 'in'),
#  (1, 'Management'),
#  (1, 'All'),
#  (1, 'India'),
#  (1, 'Council'),
#  (1, 'Technical'),
#  (1, 'Education'),
# ...

# %%
wordcount
# Out:
# 133

# %% [markdown]
# #### Consider the US weather History Dataset (KSEA.csv) attached. This dataset contains observations on Temperature in US and changes in it. Following are the fields in the dataset:
#
# A) Which day was the maximum temperature recorded?
# B) Highest rainfall or snow recorded in which year?
# C)  What is generally the distribution of temperature that a particular year have? You do not have to be very specific here but generally try to find out what proportion of high, low, medium temperature in a year? You can try and put temperature into high, low, and medium bucket based on data given.
# D)  How much of the rainfall and the hottest recorded over last six months?
# E)  Is temperature consistent during any period of time? Examine?

# %%
import pandas as pd
uswdata = pd.read_csv('/Users/dks/AMPBA/Python/Sample Exam/KSEA.CSV')

# %%
uswdata.describe()
# Out:
#        actual_mean_temp  actual_min_temp  actual_max_temp  average_min_temp  \
# count        365.000000       365.000000       365.000000        365.000000
# mean          56.542466        48.369863        64.189041         45.046575
# std           10.437226         8.707561        12.867879          7.313657
# min           30.000000        23.000000        37.000000         35.000000
# 25%           49.000000        43.000000        54.000000         37.000000
# 50%           56.000000        49.000000        62.000000         44.000000
# 75%           65.000000        55.000000        75.000000         52.000000
# max           80.000000        65.000000        96.000000         57.000000
#
#        average_max_temp  record_min_temp  record_max_temp  \
# count        365.000000       365.000000       365.000000
# mean          60.317808        31.293151        76.131507
# std           10.737519        12.273400        13.671950
# ...

# %%
uswdata
# Out:
#           date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 0     2014-7-1                77               60               94
# 1     2014-7-2                70               58               81
# 2     2014-7-3                64               57               71
# 3     2014-7-4                66               57               75
# 4     2014-7-5                66               56               76
# ..         ...               ...              ...              ...
# 360  2015-6-26                77               64               89
# 361  2015-6-27                78               63               92
# 362  2015-6-28                74               65               83
# 363  2015-6-29                74               63               84
# 364  2015-6-30                73               59               87
#
#      average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 0                  54                73               45               94
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
uswdata.plot(figsize=(20,10));

# %%
import plotly.express as px


fig = px.line(uswdata, x='date', y='actual_mean_temp', title='Time Series US weather data')
fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f78b24da36cc> in <module>
#       2
#       3
# ----> 4 fig = px.line(uswdata, x='date', y='actual_mean_temp', title='Time Series US weather data')
#       5 fig.update_xaxes(rangeslider_visible=True)
#       6 fig.show()
#
# NameError: name 'uswdata' is not defined

# %% [markdown]
# #### we can observe the dataset has observations from Jul 2014 to  Jun 2015 , a period of one year and the dataset has 365 rows with nomissing data for all columns

# %%
uswdata.median()
# Out:
# actual_mean_temp           56.00
# actual_min_temp            49.00
# actual_max_temp            62.00
# average_min_temp           44.00
# average_max_temp           59.00
# record_min_temp            33.00
# record_max_temp            76.00
# record_min_temp_year     1955.00
# record_max_temp_year     1985.00
# actual_precipitation        0.00
# average_precipitation       0.09
# record_precipitation        0.96
# dtype: float64

# %%
uswdata.mean()
# Out:
# actual_mean_temp           56.542466
# actual_min_temp            48.369863
# actual_max_temp            64.189041
# average_min_temp           45.046575
# average_max_temp           60.317808
# record_min_temp            31.293151
# record_max_temp            76.131507
# record_min_temp_year     1962.709589
# record_max_temp_year     1983.230137
# actual_precipitation        0.102548
# average_precipitation       0.102712
# record_precipitation        1.107178
# dtype: float64

# %%
uswdata.hist(bins=50, figsize=(20,12))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-494b54c0eb65> in <module>
#       1 uswdata.hist(bins=50, figsize=(20,12))
#       2
# ----> 3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.boxplot(uswdata.actual_mean_temp)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x121beb5b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x121bebc70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x121beb250>],
#  'medians': [<matplotlib.lines.Line2D at 0x121abf370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x121abf670>],
#  'means': []}

# %%
fig = plt.figure()
fig.set_size_inches(20,5)
plt.plot(uswdata.actual_mean_temp,uswdata.average_max_temp, ".",color ='blue');
plt.ylabel("average_max_temp");

# %%
maxtemp = uswdata[uswdata.actual_mean_temp > 77]

# %%
maxtemp
# Out:
#           date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 41   2014-8-11                80               64               96
# 361  2015-6-27                78               63               92
#
#      average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 41                 56                77               46               96
# 361                53                72               45               92
#
#      record_min_temp_year  record_max_temp_year  actual_precipitation  \
# 41                   1954                  2014                  0.02
# 361                  1949                  2015                  0.00
#
#      average_precipitation  record_precipitation
# 41                    0.03                  0.32
# 361                   0.04                  0.61

# %% [markdown]
# #### As we can see the maximum actual mean temp recorded was on date 11th August 2014

# %%
uswdata.actual_precipitation.max()
# Out:
# 2.2

# %%
maxprecip = uswdata[uswdata.record_precipitation > 3]
maxprecip
# Out:
#            date  actual_mean_temp  actual_min_temp  actual_max_temp  \
# 111  2014-10-20                58               54               61
# 128   2014-11-6                57               51               62
# 142  2014-11-20                47               42               52
# 147  2014-11-25                53               49               57
# 155   2014-12-3                41               32               50
# 222    2015-2-8                53               47               59
#
#      average_min_temp  average_max_temp  record_min_temp  record_max_temp  \
# 111                45                58               29               69
# 128                42                53               30               65
# 142                39                50               25               64
# 147                38                49               18               59
# 155                36                47               27               60
# ...

# %%
record_precip = uswdata['record_precipitation']

# %%
max(record_precip)
# Out:
# 5.02

# %%
# data['Tempdist'] = ""
# data1 = data.sort_values(by='actual_mean_temp',ascending=True)
# data1['Tempdist'][1:123].fillna("Low",inplace = True)
# data1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-04a62764ae31> in <module>
#       6
#       7
# ----> 8 kseaData['actual_mean_temp'].plot(kind='box')
#
# NameError: name 'kseaData' is not defined
